# %% [markdown]
# ## Practical_Activity_1.1.11

# %% [markdown]
# ### 1. Prepare your workstation

# %%
# Import necessary libraries.
import pandas as pd
import random
# %matplotlib inline
from dataclasses import dataclass
from sensitivity import SensitivityAnalyzer

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ### 2. Specify the model inputs and create a class

# %%
# Create a class and instance
@dataclass
class ModelInputs:
    share_no: int = 500
    buying_price: int = 10
    dividend: int = 500
    selling_price: int = 15
    costs: int = 125
    
model_data = ModelInputs()

model_data
# Out:
# ModelInputs(share_no=500, buying_price=10, dividend=500, selling_price=15, costs=125)

# %% [markdown]
# ### 3. Create a function to calculate ROI

# %%
# Create function to calculate ROI:
def roi_per_year(data: ModelInputs):
    year = 0
    prior_roi = 0
    
    while year < 6:
        year = year + 1
        # print(year)
        net_return = (data.selling_price - data.buying_price) \
        * data.share_no + data.dividend - data.costs
        cost_of_investment = data.buying_price * data.share_no
        
        roi = prior_roi + ((net_return) / (cost_of_investment)) * 100
        print(f'The ROI at year {year} is {roi:,.0f}%.')
        
        prior_roi = roi
        
    return roi

# View the output
roi_per_year(model_data)
# Out:
# The ROI at year 1 is 57%.
# The ROI at year 2 is 115%.
# The ROI at year 3 is 172%.
# The ROI at year 4 is 230%.
# The ROI at year 5 is 287%.
# The ROI at year 6 is 345%.
# 344.99999999999994

# %%
# Create a DataFrame to display the values generated. 
def roi_per_year_df(data: ModelInputs):
    year = 0
    prior_roi = 0
    df_data_tups = []
    
    for year in range(6):
        year = year + 1
        net_return = (data.selling_price - data.buying_price) \
        * data.share_no + data.dividend - data.costs
        cost_of_investment = data.buying_price * data.share_no
        roi = prior_roi + ((net_return) / (cost_of_investment)) * 100
        
        prior_roi = roi
        # Save the results in a tuple for later building the DataFrame.
        df_data_tups.append((year, roi))
        # Now create the DataFrame.
        df = pd.DataFrame(df_data_tups, columns = ['Year', 'ROI in %'])
        
    return df

# View the output
roi_per_year_df(model_data)
# Out:
#    Year  ROI in %
# 0     1      57.5
# 1     2     115.0
# 2     3     172.5
# 3     4     230.0
# 4     5     287.5
# 5     6     345.0

# %% [markdown]
# ### 4. Create a function to show ROI for each year and a single year

# %%
# Function to give annual ROI for each year:
def annualised_roi_per_year(data: ModelInputs):
    year = 0
    prior_roi = 0
    
    for year in range(6):
        year = year + 1
         # print(year)
        net_return = (data.selling_price - data.buying_price) \
        * data.share_no + data.dividend - data.costs
        cost_of_investment = data.buying_price * data.share_no
        
        roi = prior_roi + ((net_return) / (cost_of_investment)) * 100
        print(f'ROI: {roi}')
        
        annual_roi = ((1 + (roi / 100)) ** (1 / year) - 1) * 100
        print(f'The annualised ROI at year {year} is {annual_roi}%.')
        prior_roi = roi
        
    return annual_roi

# View output.
annualised_roi_per_year(model_data)
# Out:
# ROI: 57.49999999999999
# The annualised ROI at year 1 is 57.49999999999999%.
# ROI: 114.99999999999999
# The annualised ROI at year 2 is 46.628782986151805%.
# ROI: 172.49999999999997
# The annualised ROI at year 3 is 39.67612206238158%.
# ROI: 229.99999999999997
# The annualised ROI at year 4 is 34.78094125129469%.
# ROI: 287.49999999999994
# The annualised ROI at year 5 is 31.1155923590563%.
# ROI: 344.99999999999994
# The annualised ROI at year 6 is 28.25077608160358%.
# 28.25077608160358

# %%
# Function to return annualised ROI for a single year:
def anl_roi_per_year(data: ModelInputs, print_output = True):
    year = 0
    prior_roi = 0
    
    if print_output:
        print(f'Annual ROI over time:')
        
    while year < 10:
        year = year + 1
        net_return = (data.selling_price - data.buying_price) \
        * data.share_no + data.dividend - data.costs
        cost_of_investment = data.buying_price * data.share_no
        
        # Cost of investment is simply the buying price of each 
        # share multiplied by the number of shares purchased.
        roi = prior_roi + ((net_return) / (cost_of_investment)) * 100
        print(f'ROI: {roi}')
        
        anl_roi = ((1 + (roi / 100)) ** (1 / year) - 1) * 100
        
        return anl_roi
    
# View output.
anl_roi_per_year(model_data)
# Out:
# Annual ROI over time:
# ROI: 57.49999999999999
# 57.49999999999999

# %% [markdown]
# ### 5. Run the model based on some changes
# * a.    Initial investment increases by 10% and decreases by 10%.
# * b.    Buying price per share increases by 15% and decreases by 10%.
# * c.    Selling price per share increases by 20% and decreases by 15%.
# * d.    Annual dividend increases by 25% and decreases by 20%.

# %% [markdown]
# #### a)    Initial investment increases by 10% and decreases by 10%.

# %%
# investment = buying price * share
# NOTE : Assuming that instead of investment, the variable to be used is share no.

# %%
# Buying Share per share increases by 10%.
@dataclass
class ModelInputs:
    share_no : int = 550
    buying_price: int = 11.5
    dividend: int = 500
    selling_price: int = 15
    costs: int = 125
        
model_data = ModelInputs
model_data

roi_per_year(model_data)
# Out:
# The ROI at year 1 is 36%.
# The ROI at year 2 is 73%.
# The ROI at year 3 is 109%.
# The ROI at year 4 is 145%.
# The ROI at year 5 is 182%.
# The ROI at year 6 is 218%.
# 218.18181818181822

# %%
# Buying Share per share decreases by 10%.
@dataclass
class ModelInputs:
    share_no : int = 450
    buying_price: int = 11.5
    dividend: int = 500
    selling_price: int = 15
    costs: int = 125
        
model_data = ModelInputs()
model_data

roi_per_year(model_data)
# Out:
# The ROI at year 1 is 38%.
# The ROI at year 2 is 75%.
# The ROI at year 3 is 113%.
# The ROI at year 4 is 151%.
# The ROI at year 5 is 188%.
# The ROI at year 6 is 226%.
# 226.08695652173918

# %% [markdown]
# #### b) Buying price per share increases by 15% and decreases by 10%

# %%
# Buying price per share increases by 15%.
@dataclass
class ModelInputs:
    share_no : int = 500
    buying_price: int = 11.5
    dividend: int = 500
    selling_price: int = 15
    costs: int = 125
        
model_data = ModelInputs()
model_data

roi_per_year(model_data)
# Out:
# The ROI at year 1 is 37%.
# The ROI at year 2 is 74%.
# The ROI at year 3 is 111%.
# The ROI at year 4 is 148%.
# The ROI at year 5 is 185%.
# The ROI at year 6 is 222%.
# 221.7391304347826

# %%
# Buying price per share decreases by 15%.
@dataclass
class ModelInputs:
    share_no : int = 500
    buying_price: int = 8.5
    dividend: int = 500
    selling_price: int = 15
    costs: int = 125
        
model_data = ModelInputs()
model_data

roi_per_year(model_data)
# Out:
# The ROI at year 1 is 85%.
# The ROI at year 2 is 171%.
# The ROI at year 3 is 256%.
# The ROI at year 4 is 341%.
# The ROI at year 5 is 426%.
# The ROI at year 6 is 512%.
# 511.764705882353

# %% [markdown]
# #### c) Selling price per share increases by 20% and decreases by 15%.

# %%
# Selling price per share increases by 20%
@dataclass
class ModelInputs:
    share_no : int = 500
    buying_price: int = 10
    dividend: int = 500
    selling_price: int = 18
    costs: int = 125
        
model_data = ModelInputs()
model_data

roi_per_year(model_data)
# Out:
# The ROI at year 1 is 88%.
# The ROI at year 2 is 175%.
# The ROI at year 3 is 262%.
# The ROI at year 4 is 350%.
# The ROI at year 5 is 438%.
# The ROI at year 6 is 525%.
# 525.0

# %%
# Selling price per share decreases by 20%
@dataclass
class ModelInputs:
    share_no : int = 500
    buying_price: int = 10
    dividend: int = 500
    selling_price: int = 12
    costs: int = 125
        
model_data = ModelInputs()
model_data

roi_per_year(model_data)
# Out:
# The ROI at year 1 is 28%.
# The ROI at year 2 is 55%.
# The ROI at year 3 is 83%.
# The ROI at year 4 is 110%.
# The ROI at year 5 is 138%.
# The ROI at year 6 is 165%.
# 165.00000000000003

# %% [markdown]
# #### d) Annual dividend increases by 25% and decreases by 20%.

# %%
# Annual dividend increases by 25%.
@dataclass
class ModelInputs:
    share_no : int = 500
    buying_price: int = 10
    dividend: int = 625
    selling_price: int = 15
    costs: int = 125
        
model_data = ModelInputs()
model_data

roi_per_year(model_data)
# Out:
# The ROI at year 1 is 60%.
# The ROI at year 2 is 120%.
# The ROI at year 3 is 180%.
# The ROI at year 4 is 240%.
# The ROI at year 5 is 300%.
# The ROI at year 6 is 360%.
# 360.0

# %%
# Annual dividend decreases by 20%.
@dataclass
class ModelInputs:
    share_no : int = 500
    buying_price: int = 10
    dividend: int = 400
    selling_price: int = 15
    costs: int = 125
        
model_data = ModelInputs()
model_data

roi_per_year(model_data)
# Out:
# The ROI at year 1 is 56%.
# The ROI at year 2 is 111%.
# The ROI at year 3 is 167%.
# The ROI at year 4 is 222%.
# The ROI at year 5 is 278%.
# The ROI at year 6 is 333%.
# 333.00000000000006

# %% [markdown]
# ### 6. Create a 'good' and 'bad' scenario

# %%
# Create a good bad scenario.
@dataclass
class ModelInputs:
    share_no : int = 500
    buying_price: int = 10
    dividend: int = 500
    selling_price: int = 15
    costs: int = 125
        
model_data = ModelInputs()
model_data
# Out:
# ModelInputs(share_no=500, buying_price=10, dividend=500, selling_price=15, costs=125)

# %%
bad_economy_data = ModelInputs(
    share_no = 100,
    buying_price = 45,
    dividend = 200,
    selling_price = 30,
    costs = 300)

good_economy_data = ModelInputs(
    share_no= 800,
    buying_price= 30,
    dividend= 600,
    selling_price= 55,
    costs= 100)

cases = {
    'Bad': bad_economy_data,
    'Normal': model_data, # Original inputs were set to assume a normal economy
    'Good': good_economy_data}

for case_type, case_inputs in cases.items():
    roi = anl_roi_per_year(case_inputs, print_output=False)
    print(f'Annualised ROI would be {roi} in case of {case_type} economy.')
# Out:
# ROI: -35.55555555555556
# Annualised ROI would be -35.555555555555564 in case of Bad economy.
# ROI: 57.49999999999999
# Annualised ROI would be 57.49999999999999 in case of Normal economy.
# ROI: 85.41666666666666
# Annualised ROI would be 85.41666666666666 in case of Good economy.

# %% [markdown]
# ### 7. Perform a what-if scenario

# %%
# Run what-if analysis.
def analyser_what_if(
    share_no  = 500,
    buying_price = 10,
    dividend = 500,
    selling_price = 15,
    costs = 125):
    data = ModelInputs(
        share_no = share_no, 
        buying_price = buying_price, 
        dividend = dividend, 
        selling_price = selling_price,  
        costs = costs)
    
    return annualised_roi_per_year(data)

analyser_what_if()
# Out:
# ROI: 57.49999999999999
# The annualised ROI at year 1 is 57.49999999999999%.
# ROI: 114.99999999999999
# The annualised ROI at year 2 is 46.628782986151805%.
# ROI: 172.49999999999997
# The annualised ROI at year 3 is 39.67612206238158%.
# ROI: 229.99999999999997
# The annualised ROI at year 4 is 34.78094125129469%.
# ROI: 287.49999999999994
# The annualised ROI at year 5 is 31.1155923590563%.
# ROI: 344.99999999999994
# The annualised ROI at year 6 is 28.25077608160358%.
# 28.25077608160358

# %%
# Use Python's 'list comprehensions' syntax to make it easier to adjust the inputs;
# Use i (the iterator) as a temporary variable to store the values's position in the range:
sensitivity_values = {
    'share_no': [i * 100 for i in range(4, 8)],
    'buying_price': [i * 10 for i in range(4, 8)],
    'dividend': [i * 100 for i in range(1, 4)],
    'selling_price': [i * 10 for i in range(10, 25, 5)],
    'costs': [i * 100 for i in range(3, 10)]}

sensitivity_values
# Out:
# {'share_no': [400, 500, 600, 700],
#  'buying_price': [40, 50, 60, 70],
#  'dividend': [100, 200, 300],
#  'selling_price': [100, 150, 200],
#  'costs': [300, 400, 500, 600, 700, 800, 900]}

# %%
# Run the Python's SensitivityAnalyzer with all the assigned inputs:

sa = SensitivityAnalyzer(
    sensitivity_values,
    analyser_what_if,
    result_name = 'Annual ROI',
    reverse_colors = True,
    grid_size = 3)
# Out:
#   8%|▊         | 80/1008 [00:00<00:01, 786.42it/s]
# ROI: 148.75
# The annualised ROI at year 1 is 148.74999999999997%.
# ROI: 297.5
# The annualised ROI at year 2 is 99.37402037376886%.
# ROI: 446.25
# The annualised ROI at year 3 is 76.11532558616365%.
# ROI: 595.0
# The annualised ROI at year 4 is 62.36641479360237%.
# ROI: 743.75
# The annualised ROI at year 5 is 53.194353140020255%.
# ROI: 892.5
# The annualised ROI at year 6 is 46.595875852728%.
# ROI: 148.125
# The annualised ROI at year 1 is 148.12500000000003%.
# ROI: 296.25
# The annualised ROI at year 2 is 99.06029237394382%.
# ROI: 444.375
# The annualised ROI at year 3 is 75.91358964145543%.
# ROI: 592.5
# The annualised ROI at year 4 is 62.22020445641638%.
# ROI: 740.625
# The annualised ROI at year 5 is 53.08070735232244%.
# ROI: 888.75
# The annualised ROI at year 6 is 46.503415401138156%.
# ROI: 147.5
# The annualised ROI at year 1 is 147.5%.
# ROI: 295.0
# The annualised ROI at year 2 is 98.74606914351791%.
# ROI: 442.5
# The annualised ROI at year 3 is 75.71138993493476%.
# ROI: 590.0
# The annualised ROI at year 4 is 62.073597705262884%.
# ROI: 737.5
# The annualised ROI at year 5 is 52.966723080422625%.
# ROI: 885.0
# The annualised ROI at year 6 is 46.410662259807836%.
# ROI: 146.875
# The annualised ROI at year 1 is 146.875%.
# ROI: 293.75
# The annualised ROI at year 2 is 98.4313483298443%.
# ROI: 440.625
# The annualised ROI at year 3 is 75.50872379207195%.
# ROI: 587.5
# The annualised ROI at year 4 is 61.926592023218305%.
# ROI: 734.375
# The annualised ROI at year 5 is 52.85239804751238%.
# ROI: 881.25
# The annualised ROI at year 6 is 46.317614382597824%.
# ROI: 146.25
# The annualised ROI at year 1 is 146.25%.
# ROI: 292.5
# The annualised ROI at year 2 is 98.1161275615895%.
# ROI: 438.75
# The annualised ROI at year 3 is 75.30558851357294%.
# ROI: 585.0
# The annualised ROI at year 4 is 61.77918486815539%.
# ROI: 731.25
# The annualised ROI at year 5 is 52.737729952870694%.
# ROI: 877.5
# The annualised ROI at year 6 is 46.224269701177874%.
# ROI: 145.625
# The annualised ROI at year 1 is 145.62499999999997%.
# ROI: 291.25
# The annualised ROI at year 2 is 97.80040444852483%.
# ROI: 436.875
# The annualised ROI at year 3 is 75.1019813750631%.
# ROI: 582.5
# The annualised ROI at year 4 is 61.63137367239773%.
# ROI: 728.125
# The annualised ROI at year 5 is 52.62271647152179%.
# ROI: 873.75
# The annualised ROI at year 6 is 46.13062612469969%.
# ROI: 145.0
# The annualised ROI at year 1 is 145.00000000000003%.
# ROI: 290.0
# The annualised ROI at year 2 is 97.48417658131498%.
# ROI: 435.0
# The annualised ROI at year 3 is 74.8978996267655%.
# ROI: 580.0
# The annualised ROI at year 4 is 61.483155842368255%.
# ROI: 725.0
# The annualised ROI at year 5 is 52.50735525388686%.
# ROI: 870.0
# The annualised ROI at year 6 is 46.03668153946414%.
# ROI: 273.75
# The annualised ROI at year 1 is 273.75%.
# ROI: 547.5
# The annualised ROI at year 2 is 154.4602129999894%.
# ROI: 821.25
# The annualised ROI at year 3 is 109.63276710298273%.
# ROI: 1095.0
# The annualised ROI at year 4 is 85.92679213843068%.
# ROI: 1368.75
# The annualised ROI at year 5 is 71.15499412593547%.
# ROI: 1642.5
# The annualised ROI at year 6 is 61.0134409126198%.
# ROI: 273.125
# The annualised ROI at year 1 is 273.125%.
# ROI: 546.25
# The annualised ROI at year 2 is 154.21447637772326%.
# ROI: 819.375
# The annualised ROI at year 3 is 109.49045017729624%.
# ROI: 1092.5
# The annualised ROI at year 4 is 85.82947371088369%.
# ROI: 1365.625
# The annualised ROI at year 5 is 71.08210014968783%.
# ROI: 1638.75
# The annualised ROI at year 6 is 60.95563674767648%.
# ROI: 272.5
# The annualised ROI at year 1 is 272.5%.
# ROI: 545.0
# The annualised ROI at year 2 is 153.96850198400588%.
# ROI: 817.5
# The annualised ROI at year 3 is 109.34793962299017%.
# ROI: 1090.0
# The annualised ROI at year 4 is 85.73200214642785%.
# ROI: 1362.5
# The annualised ROI at year 5 is 71.00908172779623%.
# ROI: 1635.0
# The annualised ROI at year 6 is 60.89772859961946%.
# ROI: 271.875
# The annualised ROI at year 1 is 271.875%.
# ROI: 543.75
# The annualised ROI at year 2 is 153.7222891273055%.
# ROI: 815.625
# The annualised ROI at year 3 is 109.2052347801161%.
# ROI: 1087.5
# The annualised ROI at year 4 is 85.63437688161521%.
# ROI: 1359.375
# The annualised ROI at year 5 is 70.93593838121353%.
# ROI: 1631.25
# The annualised ROI at year 6 is 60.83971605603995%.
# ROI: 271.25
# The annualised ROI at year 1 is 271.25%.
# ROI: 542.5
# The annualised ROI at year 2 is 153.4758371127315%.
# ROI: 813.75
# The annualised ROI at year 3 is 109.0623349851194%.
# ROI: 1085.0
# The annualised ROI at year 4 is 85.53659734973316%.
# ROI: 1356.25
# The annualised ROI at year 5 is 70.86266962801788%.
# ROI: 1627.5
# The annualised ROI at year 6 is 60.78159870199589%.
# ROI: 270.625
# The annualised ROI at year 1 is 270.625%.
# ROI: 541.25
# The annualised ROI at year 2 is 153.22914524201198%.
# ROI: 811.875
# The annualised ROI at year 3 is 108.91923957081202%.
# ROI: 1082.5
# The annualised ROI at year 4 is 85.43866298077862%.
# ROI: 1353.125
# The annualised ROI at year 5 is 70.78927498338928%.
# ROI: 1623.75
# The annualised ROI at year 6 is 60.723376119990725%.
# ROI: 270.0
# The annualised ROI at year 1 is 270.0%.
# ROI: 540.0
# The annualised ROI at year 2 is 152.98221281347034%.
# ROI: 810.0
# The annualised ROI at year 3 is 108.77594786634491%.
# ROI: 1080.0
# The annualised ROI at year 4 is 85.34057320143191%.
# ROI: 1350.0
# The annualised ROI at year 5 is 70.71575395958583%.
# ROI: 1620.0
# The annualised ROI at year 6 is 60.66504788995226%.
# ROI: 398.75
# The annualised ROI at year 1 is 398.75%.
# ROI: 797.5
# The annualised ROI at year 2 is 199.58304357890486%.
# ROI: 1196.25
# The annualised ROI at year 3 is 134.9071611550876%.
# ROI: 1595.0
# The annualised ROI at year 4 is 102.90484888360308%.
# ROI: 1993.75
# The annualised ROI at year 5 is 83.73206867796696%.
# ROI: 2392.5
# The annualised ROI at year 6 is 70.91198880048712%.
# ROI: 398.125
# The annualised ROI at year 1 is 398.125%.
# ROI: 796.25
# The annualised ROI at year 2 is 199.3743475984541%.
# ROI: 1194.375
# The annualised ROI at year 3 is 134.7938436453885%.
# ROI: 1592.5
# The annualised ROI at year 4 is 102.82999004449125%.
# ROI: 1990.625
# The annualised ROI at year 5 is 83.67719051145994%.
# ROI: 2388.75
# The annualised ROI at year 6 is 70.86910534290655%.
# ROI: 397.5
# The annualised ROI at year 1 is 397.49999999999994%.
# ROI: 795.0
# The annualised ROI at year 2 is 199.16550603303182%.
# ROI: 1192.5
# The annualised ROI at year 3 is 134.6804166501302%.
# ROI: 1590.0
# The annualised ROI at year 4 is 102.7550482286173%.
# ROI: 1987.5
# The annualised ROI at year 5 is 83.62224668155048%.
# ROI: 2385.0
# The annualised ROI at year 6 is 70.82616800484483%.
# ROI: 396.875
# The annualised ROI at year 1 is 396.875%.
# ROI: 793.75
# The annualised ROI at year 2 is 198.95651857753495%.
# ROI: 1190.625
# The annualised ROI at year 3 is 134.56687990447088%.
# ROI: 1587.5
# The annualised ROI at year 4 is 102.68002322105514%.
# ROI: 1984.375
# The annualised ROI at year 5 is 83.56723701119513%.
# ROI: 2381.25
# The annualised ROI at year 6 is 70.78317663714235%.
# ROI: 396.25
# The annualised ROI at year 1 is 396.25000000000006%.
# ROI: 792.5
# The annualised ROI at year 2 is 198.7473849257931%.
# ROI: 1188.75
# The annualised ROI at year 3 is 134.4532331425421%.
# ROI: 1585.0
# The annualised ROI at year 4 is 102.60491480600264%.
# ROI: 1981.25
# The annualised ROI at year 5 is 83.51216132260679%.
# ROI: 2377.5
# The annualised ROI at year 6 is 70.74013109000043%.
# ROI: 395.625
# The annualised ROI at year 1 is 395.625%.
# ROI: 791.25
# The annualised ROI at year 2 is 198.53810477056356%.
# ROI: 1186.875
# The annualised ROI at year 3 is 134.3394760974435%.
# ROI: 1582.5
# The annualised ROI at year 4 is 102.52972276677656%.
# ROI: 1978.125
# The annualised ROI at year 5 is 83.4570194372505%.
# ROI: 2373.75
# The annualised ROI at year 6 is 70.69703121297748%.
# ROI: 395.0
# The annualised ROI at year 1 is 395.0%.
# ROI: 790.0
# The annualised ROI at year 2 is 198.32867780352595%.
# ROI: 1185.0
# The annualised ROI at year 3 is 134.22560850123722%.
# ROI: 1580.0
# The annualised ROI at year 4 is 102.45444688580787%.
# ROI: 1975.0
# The annualised ROI at year 5 is 83.40181117583907%.
# ROI: 2370.0
# The annualised ROI at year 6 is 70.65387685498538%.
# ROI: 149.375
# The annualised ROI at year 1 is 149.375%.
# ROI: 298.75
# The annualised ROI at year 2 is 99.68725547715857%.
# ROI: 448.125
# The annualised ROI at year 3 is 76.31660041913617%.
# ROI: 597.5
# The annualised ROI at year 4 is 62.512231208880124%.
# ROI: 746.875
# The annualised ROI at year 5 is 53.307662696748004%.
# ROI: 896.25
# The annualised ROI at year 6 is 46.6880456388463%.
# ROI: 148.75
# The annualised ROI at year 1 is 148.74999999999997%.
# ROI: 297.5
# The annualised ROI at year 2 is 99.37402037376886%.
# ROI: 446.25
# The annualised ROI at year 3 is 76.11532558616365%.
# ROI: 595.0
# The annualised ROI at year 4 is 62.36641479360237%.
# ROI: 743.75
# The annualised ROI at year 5 is 53.194353140020255%.
# ROI: 892.5
# The annualised ROI at year 6 is 46.595875852728%.
# ROI: 148.125
# The annualised ROI at year 1 is 148.12500000000003%.
# ROI: 296.25
# The annualised ROI at year 2 is 99.06029237394382%.
# ROI: 444.375
# The annualised ROI at year 3 is 75.91358964145543%.
# ROI: 592.5
# The annualised ROI at year 4 is 62.22020445641638%.
# ROI: 740.625
# The annualised ROI at year 5 is 53.08070735232244%.
# ROI: 888.75
# The annualised ROI at year 6 is 46.503415401138156%.
# ROI: 147.5
# The annualised ROI at year 1 is 147.5%.
# ROI: 295.0
# The annualised ROI at year 2 is 98.74606914351791%.
# ROI: 442.5
# The annualised ROI at year 3 is 75.71138993493476%.
# ROI: 590.0
# The annualised ROI at year 4 is 62.073597705262884%.
# ROI: 737.5
# The annualised ROI at year 5 is 52.966723080422625%.
# ROI: 885.0
# The annualised ROI at year 6 is 46.410662259807836%.
# ROI: 146.875
# The annualised ROI at year 1 is 146.875%.
# ROI: 293.75
# The annualised ROI at year 2 is 98.4313483298443%.
# ROI: 440.625
# The annualised ROI at year 3 is 75.50872379207195%.
# ROI: 587.5
# The annualised ROI at year 4 is 61.926592023218305%.
# ROI: 734.375
# The annualised ROI at year 5 is 52.85239804751238%.
# ROI: 881.25
# The annualised ROI at year 6 is 46.317614382597824%.
# ROI: 146.25
# The annualised ROI at year 1 is 146.25%.
# ROI: 292.5
# The annualised ROI at year 2 is 98.1161275615895%.
# ROI: 438.75
# The annualised ROI at year 3 is 75.30558851357294%.
# ROI: 585.0
# The annualised ROI at year 4 is 61.77918486815539%.
# ROI: 731.25
# The annualised ROI at year 5 is 52.737729952870694%.
# ROI: 877.5
# The annualised ROI at year 6 is 46.224269701177874%.
# ROI: 145.625
# The annualised ROI at year 1 is 145.62499999999997%.
# ROI: 291.25
# The annualised ROI at year 2 is 97.80040444852483%.
# ROI: 436.875
# The annualised ROI at year 3 is 75.1019813750631%.
# ROI: 582.5
# The annualised ROI at year 4 is 61.63137367239773%.
# ROI: 728.125
# The annualised ROI at year 5 is 52.62271647152179%.
# ROI: 873.75
# The annualised ROI at year 6 is 46.13062612469969%.
# ROI: 274.375
# The annualised ROI at year 1 is 274.375%.
# ROI: 548.75
# The annualised ROI at year 2 is 154.70571253900056%.
# ROI: 823.125
# The annualised ROI at year 3 is 109.77489105641868%.
# ROI: 1097.5
# The annualised ROI at year 4 is 86.0239579892777%.
# ROI: 1371.875
# The annualised ROI at year 5 is 71.22776413273479%.
# ROI: 1646.25
# The annualised ROI at year 6 is 61.07114150434574%.
# ROI: 273.75
# The annualised ROI at year 1 is 273.75%.
# ROI: 547.5
# The annualised ROI at year 2 is 154.4602129999894%.
# ROI: 821.25
# The annualised ROI at year 3 is 109.63276710298273%.
# ROI: 1095.0
# The annualised ROI at year 4 is 85.92679213843068%.
# ROI: 1368.75
# The annualised ROI at year 5 is 71.15499412593547%.
# ROI: 1642.5
# The annualised ROI at year 6 is 61.0134409126198%.
# ROI: 273.125
# The annualised ROI at year 1 is 273.125%.
# ROI: 546.25
# The annualised ROI at year 2 is 154.21447637772326%.
# ROI: 819.375
# The annualised ROI at year 3 is 109.49045017729624%.
# ROI: 1092.5
# The annualised ROI at year 4 is 85.82947371088369%.
# ROI: 1365.625
# The annualised ROI at year 5 is 71.08210014968783%.
# ROI: 1638.75
# The annualised ROI at year 6 is 60.95563674767648%.
# ROI: 272.5
# The annualised ROI at year 1 is 272.5%.
# ROI: 545.0
# The annualised ROI at year 2 is 153.96850198400588%.
# ROI: 817.5
# The annualised ROI at year 3 is 109.34793962299017%.
# ROI: 1090.0
# The annualised ROI at year 4 is 85.73200214642785%.
# ROI: 1362.5
# The annualised ROI at year 5 is 71.00908172779623%.
# ROI: 1635.0
# The annualised ROI at year 6 is 60.89772859961946%.
# ROI: 271.875
# The annualised ROI at year 1 is 271.875%.
# ROI: 543.75
# The annualised ROI at year 2 is 153.7222891273055%.
# ROI: 815.625
# The annualised ROI at year 3 is 109.2052347801161%.
# ROI: 1087.5
# The annualised ROI at year 4 is 85.63437688161521%.
# ROI: 1359.375
# The annualised ROI at year 5 is 70.93593838121353%.
# ROI: 1631.25
# The annualised ROI at year 6 is 60.83971605603995%.
# ROI: 271.25
# The annualised ROI at year 1 is 271.25%.
# ROI: 542.5
# The annualised ROI at year 2 is 153.4758371127315%.
# ROI: 813.75
# The annualised ROI at year 3 is 109.0623349851194%.
# ROI: 1085.0
# The annualised ROI at year 4 is 85.53659734973316%.
# ROI: 1356.25
# The annualised ROI at year 5 is 70.86266962801788%.
# ROI: 1627.5
# The annualised ROI at year 6 is 60.78159870199589%.
# ROI: 270.625
# The annualised ROI at year 1 is 270.625%.
# ROI: 541.25
# The annualised ROI at year 2 is 153.22914524201198%.
# ROI: 811.875
# The annualised ROI at year 3 is 108.91923957081202%.
# ROI: 1082.5
# The annualised ROI at year 4 is 85.43866298077862%.
# ROI: 1353.125
# The annualised ROI at year 5 is 70.78927498338928%.
# ROI: 1623.75
# The annualised ROI at year 6 is 60.723376119990725%.
# ROI: 399.375
# The annualised ROI at year 1 is 399.37500000000006%.
# ROI: 798.75
# The annualised ROI at year 2 is 199.79159427842538%.
# ROI: 1198.125
# The annualised ROI at year 3 is 135.02036944304828%.
# ROI: 1597.5
# The annualised ROI at year 4 is 102.97962496000758%.
# ROI: 1996.875
# The annualised ROI at year 5 is 83.78688135737553%.
# ROI: 2396.25
# The annualised ROI at year 6 is 70.95481852611071%.
# ROI: 398.75
# The annualised ROI at year 1 is 398.75%.
# ROI: 797.5
# The annualised ROI at year 2 is 199.58304357890486%.
# ROI: 1196.25
# The annualised ROI at year 3 is 134.9071611550876%.
# ROI: 1595.0
# The annualised ROI at year 4 is 102.90484888360308%.
# ROI: 1993.75
# The annualised ROI at year 5 is 83.73206867796696%.
# ROI: 2392.5
# The annualised ROI at year 6 is 70.91198880048712%.
# ROI: 398.125
# The annualised ROI at year 1 is 398.125%.
# ROI: 796.25
# The annualised ROI at year 2 is 199.3743475984541%.
# ROI: 1194.375
# The annualised ROI at year 3 is 134.7938436453885%.
# ROI: 1592.5
# The annualised ROI at year 4 is 102.82999004449125%.
# ROI: 1990.625
# The annualised ROI at year 5 is 83.67719051145994%.
# ROI: 2388.75
# The annualised ROI at year 6 is 70.86910534290655%.
# ROI: 397.5
# The annualised ROI at year 1 is 397.49999999999994%.
# ROI: 795.0
# The annualised ROI at year 2 is 199.16550603303182%.
# ROI: 1192.5
# The annualised ROI at year 3 is 134.6804166501302%.
# ROI: 1590.0
# The annualised ROI at year 4 is 102.7550482286173%.
# ROI: 1987.5
# The annualised ROI at year 5 is 83.62224668155048%.
# ROI: 2385.0
# The annualised ROI at year 6 is 70.82616800484483%.
# ROI: 396.875
# The annualised ROI at year 1 is 396.875%.
# ROI: 793.75
# The annualised ROI at year 2 is 198.95651857753495%.
# ROI: 1190.625
# The annualised ROI at year 3 is 134.56687990447088%.
# ROI: 1587.5
# The annualised ROI at year 4 is 102.68002322105514%.
# ROI: 1984.375
# The annualised ROI at year 5 is 83.56723701119513%.
# ROI: 2381.25
# The annualised ROI at year 6 is 70.78317663714235%.
# ROI: 396.25
# The annualised ROI at year 1 is 396.25000000000006%.
# ROI: 792.5
# The annualised ROI at year 2 is 198.7473849257931%.
# ROI: 1188.75
# The annualised ROI at year 3 is 134.4532331425421%.
# ROI: 1585.0
# The annualised ROI at year 4 is 102.60491480600264%.
# ROI: 1981.25
# The annualised ROI at year 5 is 83.51216132260679%.
# ROI: 2377.5
# The annualised ROI at year 6 is 70.74013109000043%.
# ROI: 395.625
# The annualised ROI at year 1 is 395.625%.
# ROI: 791.25
# The annualised ROI at year 2 is 198.53810477056356%.
# ROI: 1186.875
# The annualised ROI at year 3 is 134.3394760974435%.
# ROI: 1582.5
# The annualised ROI at year 4 is 102.52972276677656%.
# ROI: 1978.125
# The annualised ROI at year 5 is 83.4570194372505%.
# ROI: 2373.75
# The annualised ROI at year 6 is 70.69703121297748%.
# ROI: 150.0
# The annualised ROI at year 1 is 150.0%.
# ROI: 300.0
# The annualised ROI at year 2 is 100.0%.
# ROI: 450.0
# The annualised ROI at year 3 is 76.51741676630314%.
# ROI: 600.0
# The annualised ROI at year 4 is 62.65765616977856%.
# ROI: 750.0
# The annualised ROI at year 5 is 53.4206382524911%.
# ROI: 900.0
# The annualised ROI at year 6 is 46.77992676220695%.
# ROI: 149.375
# The annualised ROI at year 1 is 149.375%.
# ROI: 298.75
# The annualised ROI at year 2 is 99.68725547715857%.
# ROI: 448.125
# The annualised ROI at year 3 is 76.31660041913617%.
# ROI: 597.5
# The annualised ROI at year 4 is 62.512231208880124%.
# ROI: 746.875
# The annualised ROI at year 5 is 53.307662696748004%.
# ROI: 896.25
# The annualised ROI at year 6 is 46.6880456388463%.
# ROI: 148.75
# The annualised ROI at year 1 is 148.74999999999997%.
# ROI: 297.5
# The annualised ROI at year 2 is 99.37402037376886%.
# ROI: 446.25
# The annualised ROI at year 3 is 76.11532558616365%.
# ROI: 595.0
# The annualised ROI at year 4 is 62.36641479360237%.
# ROI: 743.75
# The annualised ROI at year 5 is 53.194353140020255%.
# ROI: 892.5
# The annualised ROI at year 6 is 46.595875852728%.
# ROI: 148.125
# The annualised ROI at year 1 is 148.12500000000003%.
# ROI: 296.25
# The annualised ROI at year 2 is 99.06029237394382%.
# ROI: 444.375
# The annualised ROI at year 3 is 75.91358964145543%.
# ROI: 592.5
# The annualised ROI at year 4 is 62.22020445641638%.
# ROI: 740.625
# The annualised ROI at year 5 is 53.08070735232244%.
# ROI: 888.75
# The annualised ROI at year 6 is 46.503415401138156%.
# ROI: 147.5
# The annualised ROI at year 1 is 147.5%.
# ROI: 295.0
# The annualised ROI at year 2 is 98.74606914351791%.
# ROI: 442.5
# The annualised ROI at year 3 is 75.71138993493476%.
# ROI: 590.0
# The annualised ROI at year 4 is 62.073597705262884%.
# ROI: 737.5
# The annualised ROI at year 5 is 52.966723080422625%.
# ROI: 885.0
# The annualised ROI at year 6 is 46.410662259807836%.
# ROI: 146.875
# The annualised ROI at year 1 is 146.875%.
# ROI: 293.75
# The annualised ROI at year 2 is 98.4313483298443%.
# ROI: 440.625
# The annualised ROI at year 3 is 75.50872379207195%.
# ROI: 587.5
# The annualised ROI at year 4 is 61.926592023218305%.
# ROI: 734.375
# The annualised ROI at year 5 is 52.85239804751238%.
# ROI: 881.25
# The annualised ROI at year 6 is 46.317614382597824%.
# ROI: 146.25
# The annualised ROI at year 1 is 146.25%.
# ROI: 292.5
# The annualised ROI at year 2 is 98.1161275615895%.
# ROI: 438.75
# The annualised ROI at year 3 is 75.30558851357294%.
# ROI: 585.0
# The annualised ROI at year 4 is 61.77918486815539%.
# ROI: 731.25
# The annualised ROI at year 5 is 52.737729952870694%.
# ROI: 877.5
# The annualised ROI at year 6 is 46.224269701177874%.
# ROI: 275.0
# The annualised ROI at year 1 is 275.0%.
# ROI: 550.0
# The annualised ROI at year 2 is 154.9509756796392%.
# ROI: 825.0
# The annualised ROI at year 3 is 109.91682269042036%.
# ROI: 1100.0
# The annualised ROI at year 4 is 86.12097182041991%.
# ROI: 1375.0
# The annualised ROI at year 5 is 71.30041064345303%.
# ROI: 1650.0
# The annualised ROI at year 6 is 61.128738930258876%.
# ROI: 274.375
# The annualised ROI at year 1 is 274.375%.
# ROI: 548.75
# The annualised ROI at year 2 is 154.70571253900056%.
# ROI: 823.125
# The annualised ROI at year 3 is 109.77489105641868%.
# ROI: 1097.5
# The annualised ROI at year 4 is 86.0239579892777%.
# ROI: 1371.875
# The annualised ROI at year 5 is 71.22776413273479%.
# ROI: 1646.25
# The annualised ROI at year 6 is 61.07114150434574%.
# ROI: 273.75
# The annualised ROI at year 1 is 273.75%.
# ROI: 547.5
# The annualised ROI at year 2 is 154.4602129999894%.
# ROI: 821.25
# The annualised ROI at year 3 is 109.63276710298273%.
# ROI: 1095.0
# The annualised ROI at year 4 is 85.92679213843068%.
# ROI: 1368.75
# The annualised ROI at year 5 is 71.15499412593547%.
# ROI: 1642.5
# The annualised ROI at year 6 is 61.0134409126198%.
# ROI: 273.125
# The annualised ROI at year 1 is 273.125%.
# ROI: 546.25
# The annualised ROI at year 2 is 154.21447637772326%.
# ROI: 819.375
# The annualised ROI at year 3 is 109.49045017729624%.
# ROI: 1092.5
# The annualised ROI at year 4 is 85.82947371088369%.
# ROI: 1365.625
# The annualised ROI at year 5 is 71.08210014968783%.
# ROI: 1638.75
# The annualised ROI at year 6 is 60.95563674767648%.
# ROI: 272.5
# The annualised ROI at year 1 is 272.5%.
# ROI: 545.0
# The annualised ROI at year 2 is 153.96850198400588%.
# ROI: 817.5
# The annualised ROI at year 3 is 109.34793962299017%.
# ROI: 1090.0
# The annualised ROI at year 4 is 85.73200214642785%.
# ROI: 1362.5
# The annualised ROI at year 5 is 71.00908172779623%.
# ROI: 1635.0
# The annualised ROI at year 6 is 60.89772859961946%.
# ROI: 271.875
# The annualised ROI at year 1 is 271.875%.
# ROI: 543.75
# The annualised ROI at year 2 is 153.7222891273055%.
# ROI: 815.625
# The annualised ROI at year 3 is 109.2052347801161%.
# ROI: 1087.5
# The annualised ROI at year 4 is 85.63437688161521%.
# ROI: 1359.375
# The annualised ROI at year 5 is 70.93593838121353%.
# ROI: 1631.25
# The annualised ROI at year 6 is 60.83971605603995%.
# ROI: 271.25
# The annualised ROI at year 1 is 271.25%.
# ROI: 542.5
# The annualised ROI at year 2 is 153.4758371127315%.
# ROI: 813.75
# The annualised ROI at year 3 is 109.0623349851194%.
# ROI: 1085.0
# The annualised ROI at year 4 is 85.53659734973316%.
# ROI: 1356.25
# The annualised ROI at year 5 is 70.86266962801788%.
# ROI: 1627.5
# The annualised ROI at year 6 is 60.78159870199589%.
# ROI: 400.0
# The annualised ROI at year 1 is 400.0%.
# ROI: 800.0
# The annualised ROI at year 2 is 200.0%.
# ROI: 1200.0
# The annualised ROI at year 3 is 135.13346877207573%.
# ROI: 1600.0
# The annualised ROI at year 4 is 103.05431848689307%.
# ROI: 2000.0
# The annualised ROI at year 5 is 83.8416287252544%.
# ROI: 2400.0
# The annualised ROI at year 6 is 70.99759466766969%.
# ROI: 399.375
# The annualised ROI at year 1 is 399.37500000000006%.
# ROI: 798.75
# The annualised ROI at year 2 is 199.79159427842538%.
# ROI: 1198.125
# The annualised ROI at year 3 is 135.02036944304828%.
# ROI: 1597.5
# The annualised ROI at year 4 is 102.97962496000758%.
# ROI: 1996.875
# The annualised ROI at year 5 is 83.78688135737553%.
# ROI: 2396.25
# The annualised ROI at year 6 is 70.95481852611071%.
# ROI: 398.75
# The annualised ROI at year 1 is 398.75%.
# ROI: 797.5
# The annualised ROI at year 2 is 199.58304357890486%.
# ROI: 1196.25
# The annualised ROI at year 3 is 134.9071611550876%.
# ROI: 1595.0
# The annualised ROI at year 4 is 102.90484888360308%.
# ROI: 1993.75
# The annualised ROI at year 5 is 83.73206867796696%.
# ROI: 2392.5
# The annualised ROI at year 6 is 70.91198880048712%.
# ROI: 398.125
# The annualised ROI at year 1 is 398.125%.
# ROI: 796.25
# The annualised ROI at year 2 is 199.3743475984541%.
# ROI: 1194.375
# The annualised ROI at year 3 is 134.7938436453885%.
# ROI: 1592.5
# The annualised ROI at year 4 is 102.82999004449125%.
# ROI: 1990.625
# The annualised ROI at year 5 is 83.67719051145994%.
# ROI: 2388.75
# The annualised ROI at year 6 is 70.86910534290655%.
# ROI: 397.5
# The annualised ROI at year 1 is 397.49999999999994%.
# ROI: 795.0
# The annualised ROI at year 2 is 199.16550603303182%.
# ROI: 1192.5
# The annualised ROI at year 3 is 134.6804166501302%.
# ROI: 1590.0
# The annualised ROI at year 4 is 102.7550482286173%.
# ROI: 1987.5
# The annualised ROI at year 5 is 83.62224668155048%.
# ROI: 2385.0
# The annualised ROI at year 6 is 70.82616800484483%.
# ROI: 396.875
# The annualised ROI at year 1 is 396.875%.
# ROI: 793.75
# The annualised ROI at year 2 is 198.95651857753495%.
# ROI: 1190.625
# The annualised ROI at year 3 is 134.56687990447088%.
# ROI: 1587.5
# The annualised ROI at year 4 is 102.68002322105514%.
# ROI: 1984.375
# The annualised ROI at year 5 is 83.56723701119513%.
# ROI: 2381.25
# The annualised ROI at year 6 is 70.78317663714235%.
# ROI: 396.25
# The annualised ROI at year 1 is 396.25000000000006%.
# ROI: 792.5
# The annualised ROI at year 2 is 198.7473849257931%.
# ROI: 1188.75
# The annualised ROI at year 3 is 134.4532331425421%.
# ROI: 1585.0
# The annualised ROI at year 4 is 102.60491480600264%.
# ROI: 1981.25
# The annualised ROI at year 5 is 83.51216132260679%.
# ROI: 2377.5
# The annualised ROI at year 6 is 70.74013109000043%.
# ROI: 99.0
# The annualised ROI at year 1 is 99.0%.
# ROI: 198.0
# The annualised ROI at year 2 is 72.62676501632069%.
# ROI: 297.0
# The annualised ROI at year 3 is 58.34225865352987%.
# ROI: 396.0
# The annualised ROI at year 4 is 49.23490694646506%.
# ROI: 495.0
# The annualised ROI at year 5 is 42.85761428260288%.
# ROI: 594.0
# The annualised ROI at year 6 is 38.11046211472089%.
# ROI: 98.5
# The annualised ROI at year 1 is 98.49999999999999%.
# ROI: 197.0
# The annualised ROI at year 2 is 72.33687939614086%.
# ROI: 295.5
# The annualised ROI at year 3 is 58.14258346232635%.
# ROI: 394.0
# The annualised ROI at year 4 is 49.08424051821463%.
# ROI: 492.5
# The annualised ROI at year 5 is 42.737363595052116%.
# ROI: 591.0
# The annualised ROI at year 6 is 38.010779204553536%.
# ROI: 98.0
# The annualised ROI at year 1 is 98.0%.
# ROI: 196.0
# The annualised ROI at year 2 is 72.04650534085253%.
# ROI: 294.0
# The annualised ROI at year 3 is 57.942402762961365%.
# ROI: 392.0
# The annualised ROI at year 4 is 48.93311590381379%.
# ROI: 490.0
# The annualised ROI at year 5 is 42.61670631046479%.
# ROI: 588.0
# The annualised ROI at year 6 is 37.910734992299645%.
# ROI: 97.5
# The annualised ROI at year 1 is 97.50000000000001%.
# ROI: 195.0
# The annualised ROI at year 2 is 71.75564037317667%.
# ROI: 292.5
# The annualised ROI at year 3 is 57.741713343806424%.
# ROI: 390.0
# The annualised ROI at year 4 is 48.78152983881654%.
# ROI: 487.5
# The annualised ROI at year 5 is 42.49563932239633%.
# ROI: 585.0
# The annualised ROI at year 6 is 37.810326584370735%.
# ROI: 97.0
# The annualised ROI at year 1 is 97.0%.
# ROI: 194.0
# The annualised ROI at year 2 is 71.46428199482247%.
# ROI: 291.0
# The annualised ROI at year 3 is 57.54051196046106%.
# ROI: 388.0
# The annualised ROI at year 4 is 48.629479022078655%.
# ROI: 485.0
# The annualised ROI at year 5 is 42.37415948732581%.
# ROI: 582.0
# The annualised ROI at year 6 is 37.70955105120662%.
# ROI: 96.5
# The annualised ROI at year 1 is 96.49999999999999%.
# ROI: 193.0
# The annualised ROI at year 2 is 71.17242768623689%.
# ROI: 289.5
# The annualised ROI at year 3 is 57.33879533529134%.
# ROI: 386.0
# The annualised ROI at year 4 is 48.47696011519296%.
# ROI: 482.5
# The annualised ROI at year 5 is 42.2522636240529%.
# ROI: 579.0
# The annualised ROI at year 6 is 37.60840542666764%.
# ROI: 96.0
# The annualised ROI at year 1 is 96.0%.
# ROI: 192.0
# The annualised ROI at year 2 is 70.88007490635061%.
# ROI: 288.0
# The annualised ROI at year 3 is 57.13656015695994%.
# ROI: 384.0
# The annualised ROI at year 4 is 48.32396974191327%.
# ROI: 480.0
# The annualised ROI at year 5 is 42.129948513082205%.
# ROI: 576.0
# The annualised ROI at year 6 is 37.50688670741409%.
# ROI: 199.0
# The annualised ROI at year 1 is 199.00000000000003%.
# ROI: 398.0
# The annualised ROI at year 2 is 123.159136044214%.
# ROI: 597.0
# The annualised ROI at year 3 is 91.01945106769284%.
# ROI: 796.0
# The annualised ROI at year 4 is 73.01230908288443%.
# ROI: 995.0
# The annualised ROI at year 5 is 61.392304858174064%.
# ROI: 1194.0
# The annualised ROI at year 6 is 53.22244189858147%.
# ROI: 198.5
# The annualised ROI at year 1 is 198.50000000000003%.
# ROI: 397.0
# The annualised ROI at year 2 is 122.93496809607953%.
# ROI: 595.5
# The annualised ROI at year 3 is 90.8823229149875%.
# ROI: 794.0
# The annualised ROI at year 4 is 72.91568111496456%.
# ROI: 992.5
# The annualised ROI at year 5 is 61.31854234798293%.
# ROI: 1191.0
# The annualised ROI at year 6 is 53.16317966351498%.
# ROI: 198.0
# The annualised ROI at year 1 is 198.0%.
# ROI: 396.0
# The annualised ROI at year 2 is 122.71057451320088%.
# ROI: 594.0
# The annualised ROI at year 3 is 90.74499745541755%.
# ROI: 792.0
# The annualised ROI at year 4 is 72.81889088330638%.
# ROI: 990.0
# The annualised ROI at year 5 is 61.24464467960622%.
# ROI: 1188.0
# The annualised ROI at year 6 is 53.10380255678311%.
# ROI: 197.5
# The annualised ROI at year 1 is 197.5%.
# ROI: 395.0
# The annualised ROI at year 2 is 122.4859546128699%.
# ROI: 592.5
# The annualised ROI at year 3 is 90.60747397770996%.
# ROI: 790.0
# The annualised ROI at year 4 is 72.72193775068816%.
# ROI: 987.5
# The annualised ROI at year 5 is 61.170611294538205%.
# ROI: 1185.0
# The annualised ROI at year 6 is 53.04431008738521%.
# ROI: 197.0
# The annualised ROI at year 1 is 196.99999999999997%.
# ROI: 394.0
# The annualised ROI at year 2 is 122.26110770892866%.
# ROI: 591.0
# The annualised ROI at year 3 is 90.46975176648027%.
# ROI: 788.0
# The annualised ROI at year 4 is 72.6248210759469%.
# ROI: 985.0
# The annualised ROI at year 5 is 61.096441630674846%.
# ROI: 1182.0
# The annualised ROI at year 6 is 52.984701761069594%.
# ROI: 196.5
# The annualised ROI at year 1 is 196.5%.
# ROI: 393.0
# The annualised ROI at year 2 is 122.03603311174516%.
# ROI: 589.5
# The annualised ROI at year 3 is 90.33183010219989%.
# ROI: 786.0
# The annualised ROI at year 4 is 72.52754021394507%.
# ROI: 982.5
# The annualised ROI at year 5 is 61.022135122282336%.
# ROI: 1179.0
# The annualised ROI at year 6 is 52.92497708030432%.
# ROI: 196.0
# The annualised ROI at year 1 is 196.0%.
# ROI: 392.0
# The annualised ROI at year 2 is 121.81073012818833%.
# ROI: 588.0
# The annualised ROI at year 3 is 90.193708261163%.
# ROI: 784.0
# The annualised ROI at year 4 is 72.43009451553696%.
# ROI: 980.0
# The annualised ROI at year 5 is 60.94769119996513%.
# ROI: 1176.0
# The annualised ROI at year 6 is 52.865135544247764%.
# ROI: 299.0
# The annualised ROI at year 1 is 299.0%.
# ROI: 598.0
# The annualised ROI at year 2 is 164.19689627245813%.
# ROI: 897.0
# The annualised ROI at year 3 is 115.22780973092401%.
# ROI: 1196.0
# The annualised ROI at year 4 is 89.73665961010275%.
# ROI: 1495.0
# The annualised ROI at year 5 is 74.00115755968395%.
# ROI: 1794.0
# The annualised ROI at year 6 is 63.266341999977385%.
# ROI: 298.5
# The annualised ROI at year 1 is 298.5%.
# ROI: 597.0
# The annualised ROI at year 2 is 164.0075756488817%.
# ROI: 895.5
# The annualised ROI at year 3 is 115.11981783636118%.
# ROI: 1194.0
# The annualised ROI at year 4 is 89.66341633854933%.
# ROI: 1492.5
# The annualised ROI at year 5 is 73.94657751206601%.
# ROI: 1791.0
# The annualised ROI at year 6 is 63.22321259164694%.
# ROI: 298.0
# The annualised ROI at year 1 is 298.0%.
# ROI: 596.0
# The annualised ROI at year 2 is 163.81811916545837%.
# ROI: 894.0
# The annualised ROI at year 3 is 115.01171740718527%.
# ROI: 1192.0
# The annualised ROI at year 4 is 89.59008811439182%.
# ROI: 1490.0
# The annualised ROI at year 5 is 73.89192887497671%.
# ROI: 1788.0
# The annualised ROI at year 6 is 63.180026126261744%.
# ROI: 297.5
# The annualised ROI at year 1 is 297.5%.
# ROI: 595.0
# The annualised ROI at year 2 is 163.62852652928134%.
# ROI: 892.5
# The annualised ROI at year 3 is 114.90350817028441%.
# ROI: 1190.0
# The annualised ROI at year 4 is 89.51667470736169%.
# ROI: 1487.5
# The annualised ROI at year 5 is 73.83721145417258%.
# ROI: 1785.0
# The annualised ROI at year 6 is 63.13678243749663%.
# ROI: 297.0
# The annualised ROI at year 1 is 297.0%.
# ROI: 594.0
# The annualised ROI at year 2 is 163.43879744638983%.
# ROI: 891.0
# The annualised ROI at year 3 is 114.7951898514453%.
# ROI: 1188.0
# The annualised ROI at year 4 is 89.44317588620795%.
# ROI: 1485.0
# The annualised ROI at year 5 is 73.78242505455313%.
# ROI: 1782.0
# The annualised ROI at year 6 is 63.09348135827588%.
# ROI: 296.5
# The annualised ROI at year 1 is 296.5%.
# ROI: 593.0
# The annualised ROI at year 2 is 163.24893162176366%.
# ROI: 889.5
# The annualised ROI at year 3 is 114.68676217534744%.
# ROI: 1186.0
# The annualised ROI at year 4 is 89.36959141869166%.
# ROI: 1482.5
# The annualised ROI at year 5 is 73.72756948015568%.
# ROI: 1779.0
# The annualised ROI at year 6 is 63.050122720768755%.
# ROI: 296.0
# The annualised ROI at year 1 is 296.0%.
# ROI: 592.0
# The annualised ROI at year 2 is 163.0589287593181%.
# ROI: 888.0
# The annualised ROI at year 3 is 114.57822486555669%.
# ROI: 1184.0
# The annualised ROI at year 4 is 89.29592107157998%.
# ROI: 1480.0
# The annualised ROI at year 5 is 73.67264453415024%.
# ROI: 1776.0
# The annualised ROI at year 6 is 63.00670635638477%.
# ROI: 99.5
# The annualised ROI at year 1 is 99.50000000000001%.
# ROI: 199.0
# The annualised ROI at year 2 is 72.91616465790582%.
# ROI: 298.5
# The annualised ROI at year 3 is 58.541431515882046%.
# ROI: 398.0
# The annualised ROI at year 4 is 49.38511841686708%.
# ROI: 497.5
# The annualised ROI at year 5 is 42.97746144307635%.
# ROI: 597.0
# The annualised ROI at year 6 is 38.20978658101344%.
# ROI: 99.0
# The annualised ROI at year 1 is 99.0%.
# ROI: 198.0
# The annualised ROI at year 2 is 72.62676501632069%.
# ROI: 297.0
# The annualised ROI at year 3 is 58.34225865352987%.
# ROI: 396.0
# The annualised ROI at year 4 is 49.23490694646506%.
# ROI: 495.0
# The annualised ROI at year 5 is 42.85761428260288%.
# ROI: 594.0
# The annualised ROI at year 6 is 38.11046211472089%.
# ROI: 98.5
# The annualised ROI at year 1 is 98.49999999999999%.
# ROI: 197.0
# The annualised ROI at year 2 is 72.33687939614086%.
# ROI: 295.5
# The annualised ROI at year 3 is 58.14258346232635%.
# ROI: 394.0
# The annualised ROI at year 4 is 49.08424051821463%.
# ROI: 492.5
# The annualised ROI at year 5 is 42.737363595052116%.
# ROI: 591.0
# The annualised ROI at year 6 is 38.010779204553536%.
# ROI: 98.0
# The annualised ROI at year 1 is 98.0%.
# ROI: 196.0
# The annualised ROI at year 2 is 72.04650534085253%.
# ROI: 294.0
# The annualised ROI at year 3 is 57.942402762961365%.
# ROI: 392.0
# The annualised ROI at year 4 is 48.93311590381379%.
# ROI: 490.0
# The annualised ROI at year 5 is 42.61670631046479%.
# ROI: 588.0
# The annualised ROI at year 6 is 37.910734992299645%.
# ROI: 97.5
# The annualised ROI at year 1 is 97.50000000000001%.
# ROI: 195.0
# The annualised ROI at year 2 is 71.75564037317667%.
# ROI: 292.5
# The annualised ROI at year 3 is 57.741713343806424%.
# ROI: 390.0
# The annualised ROI at year 4 is 48.78152983881654%.
# ROI: 487.5
# The annualised ROI at year 5 is 42.49563932239633%.
# ROI: 585.0
# The annualised ROI at year 6 is 37.810326584370735%.
# ROI: 97.0
# The annualised ROI at year 1 is 97.0%.
# ROI: 194.0
# The annualised ROI at year 2 is 71.46428199482247%.
# ROI: 291.0
# The annualised ROI at year 3 is 57.54051196046106%.
# ROI: 388.0
# The annualised ROI at year 4 is 48.629479022078655%.
# ROI: 485.0
# The annualised ROI at year 5 is 42.37415948732581%.
# ROI: 582.0
# The annualised ROI at year 6 is 37.70955105120662%.
# ROI: 96.5
# The annualised ROI at year 1 is 96.49999999999999%.
# ROI: 193.0
# The annualised ROI at year 2 is 71.17242768623689%.
# ROI: 289.5
# The annualised ROI at year 3 is 57.33879533529134%.
# ROI: 386.0
# The annualised ROI at year 4 is 48.47696011519296%.
# ROI: 482.5
# The annualised ROI at year 5 is 42.2522636240529%.
# ROI: 579.0
# The annualised ROI at year 6 is 37.60840542666764%.
# ROI: 199.5
# The annualised ROI at year 1 is 199.5%.
# ROI: 399.0
# The annualised ROI at year 2 is 123.38307903688678%.
# ROI: 598.5
# The annualised ROI at year 3 is 91.15638262072761%.
# ROI: 798.0
# The annualised ROI at year 4 is 73.10877542037953%.
# ROI: 997.5
# The annualised ROI at year 5 is 61.46593276511825%.
# ROI: 1197.0
# The annualised ROI at year 6 is 53.28158974976112%.
# ROI: 199.0
# The annualised ROI at year 1 is 199.00000000000003%.
# ROI: 398.0
# The annualised ROI at year 2 is 123.159136044214%.
# ROI: 597.0
# The annualised ROI at year 3 is 91.01945106769284%.
# ROI: 796.0
# The annualised ROI at year 4 is 73.01230908288443%.
# ROI: 995.0
# The annualised ROI at year 5 is 61.392304858174064%.
# ROI: 1194.0
# The annualised ROI at year 6 is 53.22244189858147%.
# ROI: 198.5
# The annualised ROI at year 1 is 198.50000000000003%.
# ROI: 397.0
# The annualised ROI at year 2 is 122.93496809607953%.
# ROI: 595.5
# The annualised ROI at year 3 is 90.8823229149875%.
# ROI: 794.0
# The annualised ROI at year 4 is 72.91568111496456%.
# ROI: 992.5
# The annualised ROI at year 5 is 61.31854234798293%.
# ROI: 1191.0
# The annualised ROI at year 6 is 53.16317966351498%.
# ROI: 198.0
# The annualised ROI at year 1 is 198.0%.
# ROI: 396.0
# The annualised ROI at year 2 is 122.71057451320088%.
# ROI: 594.0
# The annualised ROI at year 3 is 90.74499745541755%.
# ROI: 792.0
# The annualised ROI at year 4 is 72.81889088330638%.
# ROI: 990.0
# The annualised ROI at year 5 is 61.24464467960622%.
# ROI: 1188.0
# The annualised ROI at year 6 is 53.10380255678311%.
# ROI: 197.5
# The annualised ROI at year 1 is 197.5%.
# ROI: 395.0
# The annualised ROI at year 2 is 122.4859546128699%.
# ROI: 592.5
# The annualised ROI at year 3 is 90.60747397770996%.
# ROI: 790.0
# The annualised ROI at year 4 is 72.72193775068816%.
# ROI: 987.5
# The annualised ROI at year 5 is 61.170611294538205%.
# ROI: 1185.0
# The annualised ROI at year 6 is 53.04431008738521%.
# ROI: 197.0
# The annualised ROI at year 1 is 196.99999999999997%.
# ROI: 394.0
# The annualised ROI at year 2 is 122.26110770892866%.
# ROI: 591.0
# The annualised ROI at year 3 is 90.46975176648027%.
# ROI: 788.0
# The annualised ROI at year 4 is 72.6248210759469%.
# ROI: 985.0
# The annualised ROI at year 5 is 61.096441630674846%.
# ROI: 1182.0
# The annualised ROI at year 6 is 52.984701761069594%.
# ROI: 196.5
# The annualised ROI at year 1 is 196.5%.
# ROI: 393.0
# The annualised ROI at year 2 is 122.03603311174516%.
# ROI: 589.5
# The annualised ROI at year 3 is 90.33183010219989%.
# ROI: 786.0
# The annualised ROI at year 4 is 72.52754021394507%.
# ROI: 982.5
# The annualised ROI at year 5 is 61.022135122282336%.
# ROI: 1179.0
# The annualised ROI at year 6 is 52.92497708030432%.
# ROI: 299.5
# The annualised ROI at year 1 is 299.5%.
# ROI: 599.0
# The annualised ROI at year 2 is 164.38608132804572%.
# ROI: 898.5
# The annualised ROI at year 3 is 115.33569336289054%.
# ROI: 1198.0
# The annualised ROI at year 4 is 89.80981815834409%.
# ROI: 1497.5
# The annualised ROI at year 5 is 74.05566921122202%.
# ROI: 1797.0
# The annualised ROI at year 6 is 63.3094145168323%.
# ROI: 299.0
# The annualised ROI at year 1 is 299.0%.
# ROI: 598.0
# The annualised ROI at year 2 is 164.19689627245813%.
# ROI: 897.0
# The annualised ROI at year 3 is 115.22780973092401%.
# ROI: 1196.0
# The annualised ROI at year 4 is 89.73665961010275%.
# ROI: 1495.0
# The annualised ROI at year 5 is 74.00115755968395%.
# ROI: 1794.0
# The annualised ROI at year 6 is 63.266341999977385%.
# ROI: 298.5
# The annualised ROI at year 1 is 298.5%.
# ROI: 597.0
# The annualised ROI at year 2 is 164.0075756488817%.
# ROI: 895.5
# The annualised ROI at year 3 is 115.11981783636118%.
# ROI: 1194.0
# The annualised ROI at year 4 is 89.66341633854933%.
# ROI: 1492.5
# The annualised ROI at year 5 is 73.94657751206601%.
# ROI: 1791.0
# The annualised ROI at year 6 is 63.22321259164694%.
# ROI: 298.0
# The annualised ROI at year 1 is 298.0%.
# ROI: 596.0
# The annualised ROI at year 2 is 163.81811916545837%.
# ROI: 894.0
# The annualised ROI at year 3 is 115.01171740718527%.
# ROI: 1192.0
# The annualised ROI at year 4 is 89.59008811439182%.
# ROI: 1490.0
# The annualised ROI at year 5 is 73.89192887497671%.
# ROI: 1788.0
# The annualised ROI at year 6 is 63.180026126261744%.
# ROI: 297.5
# The annualised ROI at year 1 is 297.5%.
# ROI: 595.0
# The annualised ROI at year 2 is 163.62852652928134%.
# ROI: 892.5
# The annualised ROI at year 3 is 114.90350817028441%.
# ROI: 1190.0
# The annualised ROI at year 4 is 89.51667470736169%.
# ROI: 1487.5
# The annualised ROI at year 5 is 73.83721145417258%.
# ROI: 1785.0
# The annualised ROI at year 6 is 63.13678243749663%.
# ROI: 297.0
# The annualised ROI at year 1 is 297.0%.
# ROI: 594.0
# The annualised ROI at year 2 is 163.43879744638983%.
# ROI: 891.0
# The annualised ROI at year 3 is 114.7951898514453%.
# ROI: 1188.0
# The annualised ROI at year 4 is 89.44317588620795%.
# ROI: 1485.0
# The annualised ROI at year 5 is 73.78242505455313%.
# ROI: 1782.0
# The annualised ROI at year 6 is 63.09348135827588%.
# ROI: 296.5
# The annualised ROI at year 1 is 296.5%.
# ROI: 593.0
# The annualised ROI at year 2 is 163.24893162176366%.
# ROI: 889.5
# The annualised ROI at year 3 is 114.68676217534744%.
# ROI: 1186.0
# The annualised ROI at year 4 is 89.36959141869166%.
# ROI: 1482.5
# The annualised ROI at year 5 is 73.72756948015568%.
# ROI: 1779.0
# The annualised ROI at year 6 is 63.050122720768755%.
# ROI: 100.0
# The annualised ROI at year 1 is 100.0%.
# ROI: 200.0
# The annualised ROI at year 2 is 73.20508075688772%.
# ROI: 300.0
# The annualised ROI at year 3 is 58.74010519681994%.
# ROI: 400.0
# The annualised ROI at year 4 is 49.53487812212205%.
# ROI: 500.0
# The annualised ROI at year 5 is 43.096908110525554%.
# ROI: 600.0
# The annualised ROI at year 6 is 38.30875542684884%.
# ROI: 99.5
# The annualised ROI at year 1 is 99.50000000000001%.
# ROI: 199.0
# The annualised ROI at year 2 is 72.91616465790582%.
# ROI: 298.5
# The annualised ROI at year 3 is 58.541431515882046%.
# ROI: 398.0
# The annualised ROI at year 4 is 49.38511841686708%.
# ROI: 497.5
# The annualised ROI at year 5 is 42.97746144307635%.
# ROI: 597.0
# The annualised ROI at year 6 is 38.20978658101344%.
# ROI: 99.0
# The annualised ROI at year 1 is 99.0%.
# ROI: 198.0
# The annualised ROI at year 2 is 72.62676501632069%.
# ROI: 297.0
# The annualised ROI at year 3 is 58.34225865352987%.
# ROI: 396.0
# The annualised ROI at year 4 is 49.23490694646506%.
# ROI: 495.0
# The annualised ROI at year 5 is 42.85761428260288%.
# ROI: 594.0
# The annualised ROI at year 6 is 38.11046211472089%.
# ROI: 98.5
# The annualised ROI at year 1 is 98.49999999999999%.
# ROI: 197.0
# The annualised ROI at year 2 is 72.33687939614086%.
# ROI: 295.5
# The annualised ROI at year 3 is 58.14258346232635%.
# ROI: 394.0
# The annualised ROI at year 4 is 49.08424051821463%.
# ROI: 492.5
# The annualised ROI at year 5 is 42.737363595052116%.
# ROI: 591.0
# The annualised ROI at year 6 is 38.010779204553536%.
# ROI: 98.0
# The annualised ROI at year 1 is 98.0%.
# ROI: 196.0
# The annualised ROI at year 2 is 72.04650534085253%.
# ROI: 294.0
# The annualised ROI at year 3 is 57.942402762961365%.
# ROI: 392.0
# The annualised ROI at year 4 is 48.93311590381379%.
# ROI: 490.0
# The annualised ROI at year 5 is 42.61670631046479%.
# ROI: 588.0
# The annualised ROI at year 6 is 37.910734992299645%.
# ROI: 97.5
# The annualised ROI at year 1 is 97.50000000000001%.
# ROI: 195.0
# The annualised ROI at year 2 is 71.75564037317667%.
# ROI: 292.5
# The annualised ROI at year 3 is 57.741713343806424%.
# ROI: 390.0
# The annualised ROI at year 4 is 48.78152983881654%.
# ROI: 487.5
# The annualised ROI at year 5 is 42.49563932239633%.
# ROI: 585.0
# The annualised ROI at year 6 is 37.810326584370735%.
# ROI: 97.0
# The annualised ROI at year 1 is 97.0%.
# ROI: 194.0
# The annualised ROI at year 2 is 71.46428199482247%.
# ROI: 291.0
# The annualised ROI at year 3 is 57.54051196046106%.
# ROI: 388.0
# The annualised ROI at year 4 is 48.629479022078655%.
# ROI: 485.0
# The annualised ROI at year 5 is 42.37415948732581%.
# ROI: 582.0
# The annualised ROI at year 6 is 37.70955105120662%.
# ROI: 200.0
# The annualised ROI at year 1 is 200.0%.
# ROI: 400.0
# The annualised ROI at year 2 is 123.60679774997898%.
# ROI: 600.0
# The annualised ROI at year 3 is 91.29311827723889%.
# ROI: 800.0
# The annualised ROI at year 4 is 73.20508075688772%.
# ROI: 1000.0
# The annualised ROI at year 5 is 61.53942662021781%.
# ROI: 1200.0
# The annualised ROI at year 6 is 53.34062370163875%.
# ROI: 199.5
# The annualised ROI at year 1 is 199.5%.
# ROI: 399.0
# The annualised ROI at year 2 is 123.38307903688678%.
# ROI: 598.5
# The annualised ROI at year 3 is 91.15638262072761%.
# ROI: 798.0
# The annualised ROI at year 4 is 73.10877542037953%.
# ROI: 997.5
# The annualised ROI at year 5 is 61.46593276511825%.
# ROI: 1197.0
# The annualised ROI at year 6 is 53.28158974976112%.
# ROI: 199.0
# The annualised ROI at year 1 is 199.00000000000003%.
# ROI: 398.0
# The annualised ROI at year 2 is 123.159136044214%.
# ROI: 597.0
# The annualised ROI at year 3 is 91.01945106769284%.
# ROI: 796.0
# The annualised ROI at year 4 is 73.01230908288443%.
# ROI: 995.0
# The annualised ROI at year 5 is 61.392304858174064%.
# ROI: 1194.0
# The annualised ROI at year 6 is 53.22244189858147%.
# ROI: 198.5
# The annualised ROI at year 1 is 198.50000000000003%.
# ROI: 397.0
# The annualised ROI at year 2 is 122.93496809607953%.
# ROI: 595.5
# The annualised ROI at year 3 is 90.8823229149875%.
# ROI: 794.0
# The annualised ROI at year 4 is 72.91568111496456%.
# ROI: 992.5
# The annualised ROI at year 5 is 61.31854234798293%.
# ROI: 1191.0
# The annualised ROI at year 6 is 53.16317966351498%.
# ROI: 198.0
# The annualised ROI at year 1 is 198.0%.
# ROI: 396.0
# The annualised ROI at year 2 is 122.71057451320088%.
# ROI: 594.0
# The annualised ROI at year 3 is 90.74499745541755%.
# ROI: 792.0
# The annualised ROI at year 4 is 72.81889088330638%.
# ROI: 990.0
# The annualised ROI at year 5 is 61.24464467960622%.
# ROI: 1188.0
# The annualised ROI at year 6 is 53.10380255678311%.
# ROI: 197.5
# The annualised ROI at year 1 is 197.5%.
# ROI: 395.0
# The annualised ROI at year 2 is 122.4859546128699%.
# ROI: 592.5
# The annualised ROI at year 3 is 90.60747397770996%.
# ROI: 790.0
# The annualised ROI at year 4 is 72.72193775068816%.
# ROI: 987.5
# The annualised ROI at year 5 is 61.170611294538205%.
# ROI: 1185.0
# The annualised ROI at year 6 is 53.04431008738521%.
# ROI: 197.0
#  16%|█▌        | 159/1008 [00:00<00:01, 603.21it/s]
# The annualised ROI at year 1 is 196.99999999999997%.
# ROI: 394.0
# The annualised ROI at year 2 is 122.26110770892866%.
# ROI: 591.0
# The annualised ROI at year 3 is 90.46975176648027%.
# ROI: 788.0
# The annualised ROI at year 4 is 72.6248210759469%.
# ROI: 985.0
# The annualised ROI at year 5 is 61.096441630674846%.
# ROI: 1182.0
# The annualised ROI at year 6 is 52.984701761069594%.
# ROI: 300.0
# The annualised ROI at year 1 is 300.0%.
# ROI: 600.0
# The annualised ROI at year 2 is 164.57513110645908%.
# ROI: 900.0
# The annualised ROI at year 3 is 115.44346900318838%.
# ROI: 1200.0
# The annualised ROI at year 4 is 89.88289221159418%.
# ROI: 1500.0
# The annualised ROI at year 5 is 74.11011265922482%.
# ROI: 1800.0
# The annualised ROI at year 6 is 63.352430307049445%.
# ROI: 299.5
# The annualised ROI at year 1 is 299.5%.
# ROI: 599.0
# The annualised ROI at year 2 is 164.38608132804572%.
# ROI: 898.5
# The annualised ROI at year 3 is 115.33569336289054%.
# ROI: 1198.0
# The annualised ROI at year 4 is 89.80981815834409%.
# ROI: 1497.5
# The annualised ROI at year 5 is 74.05566921122202%.
# ROI: 1797.0
# The annualised ROI at year 6 is 63.3094145168323%.
# ROI: 299.0
# The annualised ROI at year 1 is 299.0%.
# ROI: 598.0
# The annualised ROI at year 2 is 164.19689627245813%.
# ROI: 897.0
# The annualised ROI at year 3 is 115.22780973092401%.
# ROI: 1196.0
# The annualised ROI at year 4 is 89.73665961010275%.
# ROI: 1495.0
# The annualised ROI at year 5 is 74.00115755968395%.
# ROI: 1794.0
# The annualised ROI at year 6 is 63.266341999977385%.
# ROI: 298.5
# The annualised ROI at year 1 is 298.5%.
# ROI: 597.0
# The annualised ROI at year 2 is 164.0075756488817%.
# ROI: 895.5
# The annualised ROI at year 3 is 115.11981783636118%.
# ROI: 1194.0
# The annualised ROI at year 4 is 89.66341633854933%.
# ROI: 1492.5
# The annualised ROI at year 5 is 73.94657751206601%.
# ROI: 1791.0
# The annualised ROI at year 6 is 63.22321259164694%.
# ROI: 298.0
# The annualised ROI at year 1 is 298.0%.
# ROI: 596.0
# The annualised ROI at year 2 is 163.81811916545837%.
# ROI: 894.0
# The annualised ROI at year 3 is 115.01171740718527%.
# ROI: 1192.0
# The annualised ROI at year 4 is 89.59008811439182%.
# ROI: 1490.0
# The annualised ROI at year 5 is 73.89192887497671%.
# ROI: 1788.0
# The annualised ROI at year 6 is 63.180026126261744%.
# ROI: 297.5
# The annualised ROI at year 1 is 297.5%.
# ROI: 595.0
# The annualised ROI at year 2 is 163.62852652928134%.
# ROI: 892.5
# The annualised ROI at year 3 is 114.90350817028441%.
# ROI: 1190.0
# The annualised ROI at year 4 is 89.51667470736169%.
# ROI: 1487.5
# The annualised ROI at year 5 is 73.83721145417258%.
# ROI: 1785.0
# The annualised ROI at year 6 is 63.13678243749663%.
# ROI: 297.0
# The annualised ROI at year 1 is 297.0%.
# ROI: 594.0
# The annualised ROI at year 2 is 163.43879744638983%.
# ROI: 891.0
# The annualised ROI at year 3 is 114.7951898514453%.
# ROI: 1188.0
# The annualised ROI at year 4 is 89.44317588620795%.
# ROI: 1485.0
# The annualised ROI at year 5 is 73.78242505455313%.
# ROI: 1782.0
# The annualised ROI at year 6 is 63.09348135827588%.
# ROI: 65.83333333333333
# The annualised ROI at year 1 is 65.83333333333331%.
# ROI: 131.66666666666666
# The annualised ROI at year 2 is 52.206000757744974%.
# ROI: 197.5
# The annualised ROI at year 3 is 43.823214122341625%.
# ROI: 263.3333333333333
# The annualised ROI at year 4 is 38.062683616275294%.
# ROI: 329.16666666666663
# The annualised ROI at year 5 is 33.82128524152175%.
# ROI: 394.99999999999994
# The annualised ROI at year 6 is 30.54719150019025%.
# ROI: 65.41666666666667
# The annualised ROI at year 1 is 65.41666666666669%.
# ROI: 130.83333333333334
# The annualised ROI at year 2 is 51.93200233437765%.
# ROI: 196.25
# ...
# The annualised ROI at year 6 is 23.135127493272467%.
# ROI: 114.08163265306122
# The annualised ROI at year 1 is 114.08163265306123%.
# ROI: 228.16326530612244
# The annualised ROI at year 2 is 81.15277124739836%.
# ROI: 342.2448979591837
# The annualised ROI at year 3 is 64.14246221647333%.
# ROI: 456.3265306122449
# The annualised ROI at year 4 is 53.57921480485164%.
# ROI: 570.4081632653061
# The annualised ROI at year 5 is 46.30792761558189%.
# ROI: 684.4897959183673
# The annualised ROI at year 6 is 40.96064657999514%.
# ROI: 113.87755102040818
# The annualised ROI at year 1 is 113.87755102040815%.
# ROI: 227.75510204081635
# The annualised ROI at year 2 is 81.04007899932444%.
# ROI: 341.6326530612245
# The annualised ROI at year 3 is 64.06668082887113%.
# ROI: 455.5102040816327
# The annualised ROI at year 4 is 53.522845107412856%.
# ROI: 569.3877551020408
# The annualised ROI at year 5 is 46.263362292776876%.
# ROI: 683.265306122449
# The annualised ROI at year 6 is 40.92395240468765%.
# ROI: 113.6734693877551
# The annualised ROI at year 1 is 113.6734693877551%.
# ROI: 227.3469387755102
# The annualised ROI at year 2 is 80.92731655985787%.
# ROI: 341.0204081632653
# The annualised ROI at year 3 is 63.9908293706128%.
# ROI: 454.6938775510204
# The annualised ROI at year 4 is 53.46641324891581%.
# ROI: 568.3673469387755
# The annualised ROI at year 5 is 46.21874258883525%.
# ROI: 682.0408163265306
# The annualised ROI at year 6 is 40.88721039442864%.
# ROI: 113.46938775510205
# The annualised ROI at year 1 is 113.46938775510208%.
# ROI: 226.9387755102041
# The annualised ROI at year 2 is 80.81448379767704%.
# ROI: 340.40816326530614
# The annualised ROI at year 3 is 63.9149076794977%.
# ROI: 453.8775510204082
# The annualised ROI at year 4 is 53.40991906918102%.
# ROI: 567.3469387755102
# The annualised ROI at year 5 is 46.17406835422122%.
# ROI: 680.8163265306123
# The annualised ROI at year 6 is 40.85042041181512%.
# ROI: 113.26530612244898
# The annualised ROI at year 1 is 113.26530612244898%.
# ROI: 226.53061224489795
# The annualised ROI at year 2 is 80.70158058105025%.
# ROI: 339.7959183673469
# The annualised ROI at year 3 is 63.8389155927235%.
# ROI: 453.0612244897959
# The annualised ROI at year 4 is 53.35336240737938%.
# ROI: 566.3265306122448
# The annualised ROI at year 5 is 46.12933943875848%.
# ROI: 679.5918367346937
# The annualised ROI at year 6 is 40.81358231883314%.
# ROI: 113.06122448979592
# The annualised ROI at year 1 is 113.0612244897959%.
# ROI: 226.12244897959184
# The annualised ROI at year 2 is 80.58860677783409%.
# ROI: 339.18367346938777
# The annualised ROI at year 3 is 63.76285294688333%.
# ROI: 452.2448979591837
# The annualised ROI at year 4 is 53.29674310202861%.
# ROI: 565.3061224489796
# The annualised ROI at year 5 is 46.084555691626264%.
# ROI: 678.3673469387755
# The annualised ROI at year 6 is 40.77669597685421%.
# ROI: 112.85714285714286
# The annualised ROI at year 1 is 112.85714285714286%.
# ROI: 225.71428571428572
# The annualised ROI at year 2 is 80.4755622554715%.
# ROI: 338.57142857142856
# The annualised ROI at year 3 is 63.68671957796255%.
# ROI: 451.42857142857144
# The annualised ROI at year 4 is 53.24006099098961%.
# ROI: 564.2857142857143
# The annualised ROI at year 5 is 46.0397169613558%.
# ROI: 677.1428571428572
# The annualised ROI at year 6 is 40.73976124663143%.
# ROI: 185.51020408163265
# The annualised ROI at year 1 is 185.51020408163268%.
# ROI: 371.0204081632653
# The annualised ROI at year 2 is 117.03004588380507%.
# ROI: 556.530612244898
# The annualised ROI at year 3 is 87.24849120216827%.
# ROI: 742.0408163265306
# The annualised ROI at year 4 is 70.34652787868181%.
# ROI: 927.5510204081633
# The annualised ROI at year 5 is 59.35315961266192%.
# ROI: 1113.061224489796
# The annualised ROI at year 6 is 51.58182101520112%.
# ROI: 185.30612244897958
# The annualised ROI at year 1 is 185.30612244897958%.
# ROI: 370.61224489795916
# The annualised ROI at year 2 is 116.93599168832249%.
# ROI: 555.9183673469388
# The annualised ROI at year 3 is 87.19026716508067%.
# ROI: 741.2244897959183
# The annualised ROI at year 4 is 70.30522674147797%.
# ROI: 926.5306122448978
# The annualised ROI at year 5 is 59.321497945227875%.
# ROI: 1111.8367346938774
# The annualised ROI at year 6 is 51.556308630527155%.
# ROI: 185.10204081632654
# The annualised ROI at year 1 is 185.1020408163265%.
# ROI: 370.2040816326531
# The annualised ROI at year 2 is 116.84189669726028%.
# ROI: 555.3061224489796
# The annualised ROI at year 3 is 87.13200688520037%.
# ROI: 740.4081632653061
# The annualised ROI at year 4 is 70.26389553427465%.
# ROI: 925.5102040816327
# The annualised ROI at year 5 is 59.28981108950977%.
# ROI: 1110.6122448979593
# The annualised ROI at year 6 is 51.53077475449672%.
# ROI: 184.89795918367346
# The annualised ROI at year 1 is 184.89795918367346%.
# ROI: 369.7959183673469
# The annualised ROI at year 2 is 116.74776085748775%.
# ROI: 554.6938775510204
# The annualised ROI at year 3 is 87.07371030607437%.
# ROI: 739.5918367346939
# The annualised ROI at year 4 is 70.22253420593859%.
# ROI: 924.4897959183673
# The annualised ROI at year 5 is 59.25809900037628%.
# ROI: 1109.3877551020407
# The annualised ROI at year 6 is 51.50521934724046%.
# ROI: 184.6938775510204
# The annualised ROI at year 1 is 184.69387755102042%.
# ROI: 369.3877551020408
# The annualised ROI at year 2 is 116.65358411575859%.
# ROI: 554.0816326530612
# The annualised ROI at year 3 is 87.01537737110895%.
# ROI: 738.7755102040816
# The annualised ROI at year 4 is 70.18114270519975%.
# ROI: 923.4693877551019
# The annualised ROI at year 5 is 59.22636163257016%.
# ROI: 1108.1632653061224
# The annualised ROI at year 6 is 51.47964236877465%.
# ROI: 184.48979591836735
# The annualised ROI at year 1 is 184.48979591836735%.
# ROI: 368.9795918367347
# The annualised ROI at year 2 is 116.55936641871082%.
# ROI: 553.469387755102
# The annualised ROI at year 3 is 86.95700802356899%.
# ROI: 737.9591836734694
# The annualised ROI at year 4 is 70.13972098065085%.
# ROI: 922.4489795918367
# The annualised ROI at year 5 is 59.19459894070782%.
# ROI: 1106.938775510204
# The annualised ROI at year 6 is 51.454043779000756%.
# ROI: 184.28571428571428
# The annualised ROI at year 1 is 184.28571428571425%.
# ROI: 368.57142857142856
# The annualised ROI at year 2 is 116.4651077128664%.
# ROI: 552.8571428571429
# The annualised ROI at year 3 is 86.89860220657755%.
# ROI: 737.1428571428571
# The annualised ROI at year 4 is 70.09826898074678%.
# ROI: 921.4285714285713
# The annualised ROI at year 5 is 59.16281087927872%.
# ROI: 1105.7142857142856
# The annualised ROI at year 6 is 51.42842353770482%.
# ROI: 42.857142857142854
# The annualised ROI at year 1 is 42.85714285714286%.
# ROI: 85.71428571428571
# The annualised ROI at year 2 is 36.27702877384937%.
# ROI: 128.57142857142856
# The annualised ROI at year 3 is 31.7267512016699%.
# ROI: 171.42857142857142
# The annualised ROI at year 4 is 28.355324864059604%.
# ROI: 214.28571428571428
# The annualised ROI at year 5 is 25.73753098024454%.
# ROI: 257.1428571428571
# The annualised ROI at year 6 is 23.634685410866773%.
# ROI: 42.6530612244898
# The annualised ROI at year 1 is 42.6530612244898%.
# ROI: 85.3061224489796
# The annualised ROI at year 2 is 36.12719142367538%.
# ROI: 127.9591836734694
# The annualised ROI at year 3 is 31.609032862647467%.
# ROI: 170.6122448979592
# The annualised ROI at year 4 is 28.258708066313186%.
# ROI: 213.26530612244898
# The annualised ROI at year 5 is 25.655776989784872%.
# ROI: 255.91836734693877
# The annualised ROI at year 6 is 23.563935880950137%.
# ROI: 42.44897959183673
# The annualised ROI at year 1 is 42.44897959183673%.
# ROI: 84.89795918367346
# The annualised ROI at year 2 is 35.97718896332336%.
# ROI: 127.3469387755102
# The annualised ROI at year 3 is 31.49110355857769%.
# ROI: 169.79591836734693
# The annualised ROI at year 4 is 28.161872430609346%.
# ROI: 212.24489795918367
# The annualised ROI at year 5 is 25.573809681264414%.
# ROI: 254.69387755102042
# The annualised ROI at year 6 is 23.492983222467913%.
# ROI: 42.244897959183675
# The annualised ROI at year 1 is 42.24489795918367%.
# ROI: 84.48979591836735
# The annualised ROI at year 2 is 35.827020845768146%.
# ROI: 126.73469387755102
# The annualised ROI at year 3 is 31.372962341726975%.
# ROI: 168.9795918367347
# The annualised ROI at year 4 is 28.06481679688013%.
# ROI: 211.22448979591837
# The annualised ROI at year 5 is 25.491627798224847%.
# ROI: 253.46938775510205
# The annualised ROI at year 6 is 23.421826147940106%.
# ROI: 42.04081632653061
# The annualised ROI at year 1 is 42.0408163265306%.
# ROI: 84.08163265306122
# The annualised ROI at year 2 is 35.676686520957325%.
# ROI: 126.12244897959184
# The annualised ROI at year 3 is 31.254608257531167%.
# ROI: 168.16326530612244
# The annualised ROI at year 4 is 27.967539995364675%.
# ROI: 210.20408163265304
# The annualised ROI at year 5 is 25.409230072657984%.
# ROI: 252.24489795918365
# The annualised ROI at year 6 is 23.350463357231455%.
# ROI: 41.83673469387755
# The annualised ROI at year 1 is 41.836734693877546%.
# ROI: 83.6734693877551
# The annualised ROI at year 2 is 35.526185435787696%.
# ROI: 125.51020408163265
# The annualised ROI at year 3 is 31.13604034452775%.
# ROI: 167.3469387755102
# The annualised ROI at year 4 is 27.87004084649829%.
# ROI: 209.18367346938777
# The annualised ROI at year 5 is 25.326615224861172%.
# ROI: 251.02040816326533
# The annualised ROI at year 6 is 23.278893537382572%.
# ROI: 41.63265306122449
# The annualised ROI at year 1 is 41.6326530612245%.
# ROI: 83.26530612244898
# The annualised ROI at year 2 is 35.375517034081525%.
# ROI: 124.89795918367346
# The annualised ROI at year 3 is 31.01725763428704%.
# ROI: 166.53061224489795
# The annualised ROI at year 4 is 27.772318160800168%.
# ROI: 208.16326530612244
# The annualised ROI at year 5 is 25.243781963290424%.
# ROI: 249.79591836734693
# The annualised ROI at year 6 is 23.20711536243816%.
# ROI: 114.28571428571428
# The annualised ROI at year 1 is 114.28571428571428%.
# ROI: 228.57142857142856
# The annualised ROI at year 2 is 81.26539343499314%.
# ROI: 342.85714285714283
# The annualised ROI at year 3 is 64.2181736950216%.
# ROI: 457.1428571428571
# The annualised ROI at year 4 is 53.63552250076573%.
# ROI: 571.4285714285713
# The annualised ROI at year 5 is 46.35243870614914%.
# ROI: 685.7142857142856
# The annualised ROI at year 6 is 40.99729305714688%.
# ROI: 114.08163265306122
# The annualised ROI at year 1 is 114.08163265306123%.
# ROI: 228.16326530612244
# The annualised ROI at year 2 is 81.15277124739836%.
# ROI: 342.2448979591837
# The annualised ROI at year 3 is 64.14246221647333%.
# ROI: 456.3265306122449
# The annualised ROI at year 4 is 53.57921480485164%.
# ROI: 570.4081632653061
# The annualised ROI at year 5 is 46.30792761558189%.
# ROI: 684.4897959183673
# The annualised ROI at year 6 is 40.96064657999514%.
# ROI: 113.87755102040818
# The annualised ROI at year 1 is 113.87755102040815%.
# ROI: 227.75510204081635
# The annualised ROI at year 2 is 81.04007899932444%.
# ROI: 341.6326530612245
# The annualised ROI at year 3 is 64.06668082887113%.
# ROI: 455.5102040816327
# The annualised ROI at year 4 is 53.522845107412856%.
# ROI: 569.3877551020408
# The annualised ROI at year 5 is 46.263362292776876%.
# ROI: 683.265306122449
# The annualised ROI at year 6 is 40.92395240468765%.
# ROI: 113.6734693877551
# The annualised ROI at year 1 is 113.6734693877551%.
# ROI: 227.3469387755102
# The annualised ROI at year 2 is 80.92731655985787%.
# ROI: 341.0204081632653
# The annualised ROI at year 3 is 63.9908293706128%.
# ROI: 454.6938775510204
# The annualised ROI at year 4 is 53.46641324891581%.
# ROI: 568.3673469387755
# The annualised ROI at year 5 is 46.21874258883525%.
# ROI: 682.0408163265306
# The annualised ROI at year 6 is 40.88721039442864%.
# ROI: 113.46938775510205
# The annualised ROI at year 1 is 113.46938775510208%.
# ROI: 226.9387755102041
# The annualised ROI at year 2 is 80.81448379767704%.
# ROI: 340.40816326530614
# The annualised ROI at year 3 is 63.9149076794977%.
# ROI: 453.8775510204082
# The annualised ROI at year 4 is 53.40991906918102%.
# ROI: 567.3469387755102
# The annualised ROI at year 5 is 46.17406835422122%.
# ROI: 680.8163265306123
# The annualised ROI at year 6 is 40.85042041181512%.
# ROI: 113.26530612244898
# 100%|██████████| 1008/1008 [00:01<00:00, 590.74it/s]
# The annualised ROI at year 1 is 113.26530612244898%.
# ROI: 226.53061224489795
# The annualised ROI at year 2 is 80.70158058105025%.
# ROI: 339.7959183673469
# The annualised ROI at year 3 is 63.8389155927235%.
# ROI: 453.0612244897959
# The annualised ROI at year 4 is 53.35336240737938%.
# ROI: 566.3265306122448
# The annualised ROI at year 5 is 46.12933943875848%.
# ROI: 679.5918367346937
# The annualised ROI at year 6 is 40.81358231883314%.
# ROI: 113.06122448979592
# The annualised ROI at year 1 is 113.0612244897959%.
# ROI: 226.12244897959184
# The annualised ROI at year 2 is 80.58860677783409%.
# ROI: 339.18367346938777
# The annualised ROI at year 3 is 63.76285294688333%.
# ROI: 452.2448979591837
# The annualised ROI at year 4 is 53.29674310202861%.
# ROI: 565.3061224489796
# The annualised ROI at year 5 is 46.084555691626264%.
# ROI: 678.3673469387755
# The annualised ROI at year 6 is 40.77669597685421%.
# ROI: 185.71428571428572
# The annualised ROI at year 1 is 185.71428571428572%.
# ROI: 371.42857142857144
# The annualised ROI at year 2 is 117.12405933672376%.
# ROI: 557.1428571428571
# The annualised ROI at year 3 is 87.30667905277576%.
# ROI: 742.8571428571429
# The annualised ROI at year 4 is 70.38779899688315%.
# ROI: 928.5714285714287
# The annualised ROI at year 5 is 59.384796136817776%.
# ROI: 1114.2857142857144
# The annualised ROI at year 6 is 51.60731194827386%.
# ROI: 185.51020408163265
# The annualised ROI at year 1 is 185.51020408163268%.
# ROI: 371.0204081632653
# The annualised ROI at year 2 is 117.03004588380507%.
# ROI: 556.530612244898
# The annualised ROI at year 3 is 87.24849120216827%.
# ROI: 742.0408163265306
# The annualised ROI at year 4 is 70.34652787868181%.
# ROI: 927.5510204081633
# The annualised ROI at year 5 is 59.35315961266192%.
# ROI: 1113.061224489796
# The annualised ROI at year 6 is 51.58182101520112%.
# ROI: 185.30612244897958
# The annualised ROI at year 1 is 185.30612244897958%.
# ROI: 370.61224489795916
# The annualised ROI at year 2 is 116.93599168832249%.
# ROI: 555.9183673469388
# The annualised ROI at year 3 is 87.19026716508067%.
# ROI: 741.2244897959183
# The annualised ROI at year 4 is 70.30522674147797%.
# ROI: 926.5306122448978
# The annualised ROI at year 5 is 59.321497945227875%.
# ROI: 1111.8367346938774
# The annualised ROI at year 6 is 51.556308630527155%.
# ROI: 185.10204081632654
# The annualised ROI at year 1 is 185.1020408163265%.
# ROI: 370.2040816326531
# The annualised ROI at year 2 is 116.84189669726028%.
# ROI: 555.3061224489796
# The annualised ROI at year 3 is 87.13200688520037%.
# ROI: 740.4081632653061
# The annualised ROI at year 4 is 70.26389553427465%.
# ROI: 925.5102040816327
# The annualised ROI at year 5 is 59.28981108950977%.
# ROI: 1110.6122448979593
# The annualised ROI at year 6 is 51.53077475449672%.
# ROI: 184.89795918367346
# The annualised ROI at year 1 is 184.89795918367346%.
# ROI: 369.7959183673469
# The annualised ROI at year 2 is 116.74776085748775%.
# ROI: 554.6938775510204
# The annualised ROI at year 3 is 87.07371030607437%.
# ROI: 739.5918367346939
# The annualised ROI at year 4 is 70.22253420593859%.
# ROI: 924.4897959183673
# The annualised ROI at year 5 is 59.25809900037628%.
# ROI: 1109.3877551020407
# The annualised ROI at year 6 is 51.50521934724046%.
# ROI: 184.6938775510204
# The annualised ROI at year 1 is 184.69387755102042%.
# ROI: 369.3877551020408
# The annualised ROI at year 2 is 116.65358411575859%.
# ROI: 554.0816326530612
# The annualised ROI at year 3 is 87.01537737110895%.
# ROI: 738.7755102040816
# The annualised ROI at year 4 is 70.18114270519975%.
# ROI: 923.4693877551019
# The annualised ROI at year 5 is 59.22636163257016%.
# ROI: 1108.1632653061224
# The annualised ROI at year 6 is 51.47964236877465%.
# ROI: 184.48979591836735
# The annualised ROI at year 1 is 184.48979591836735%.
# ROI: 368.9795918367347
# The annualised ROI at year 2 is 116.55936641871082%.
# ROI: 553.469387755102
# The annualised ROI at year 3 is 86.95700802356899%.
# ROI: 737.9591836734694
# The annualised ROI at year 4 is 70.13972098065085%.
# ROI: 922.4489795918367
# The annualised ROI at year 5 is 59.19459894070782%.
# ROI: 1106.938775510204
# The annualised ROI at year 6 is 51.454043779000756%.

# %%
# Display the results using a DataFrame.
styled_dict = sa.styled_dfs(num_fmt = '{:.1f}')
# Out:
# <h2>Annual ROI by share_no vs. buying_price</h2>
# <style type="text/css">
# #T_cc053_row0_col0 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_cc053_row0_col1 {
#   background-color: #fed884;
#   color: #000000;
# }
# #T_cc053_row0_col2 {
#   background-color: #a0d669;
#   color: #000000;
# }
# #T_cc053_row0_col3, #T_cc053_row1_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_cc053_row1_col0, #T_cc053_row2_col0, #T_cc053_row3_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_cc053_row1_col1, #T_cc053_row2_col1 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_cc053_row1_col2, #T_cc053_row2_col2 {
#   background-color: #a2d76a;
#   color: #000000;
# }
# #T_cc053_row2_col3, #T_cc053_row3_col3 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_cc053_row3_col1 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_cc053_row3_col2 {
#   background-color: #a5d86a;
#   color: #000000;
# }
# </style>
# <table id="T_cc053_">
#   <caption>Annual ROI - share_no vs. buying_price</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >40</th>
#       <th class="col_heading level0 col1" >50</th>
#       <th class="col_heading level0 col2" >60</th>
#       <th class="col_heading level0 col3" >70</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >share_no</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cc053_level0_row0" class="row_heading level0 row0" >400</th>
#       <td id="T_cc053_row0_col0" class="data row0 col0" >59.4</td>
#       <td id="T_cc053_row0_col1" class="data row0 col1" >51.4</td>
#       <td id="T_cc053_row0_col2" class="data row0 col2" >44.6</td>
#       <td id="T_cc053_row0_col3" class="data row0 col3" >38.4</td>
#     </tr>
#     <tr>
#       <th id="T_cc053_level0_row1" class="row_heading level0 row1" >500</th>
#       <td id="T_cc053_row1_col0" class="data row1 col0" >59.4</td>
#       <td id="T_cc053_row1_col1" class="data row1 col1" >51.5</td>
#       <td id="T_cc053_row1_col2" class="data row1 col2" >44.6</td>
#       <td id="T_cc053_row1_col3" class="data row1 col3" >38.5</td>
#     </tr>
#     <tr>
#       <th id="T_cc053_level0_row2" class="row_heading level0 row2" >600</th>
#       <td id="T_cc053_row2_col0" class="data row2 col0" >59.5</td>
#       <td id="T_cc053_row2_col1" class="data row2 col1" >51.5</td>
#       <td id="T_cc053_row2_col2" class="data row2 col2" >44.7</td>
#       <td id="T_cc053_row2_col3" class="data row2 col3" >38.5</td>
#     </tr>
#     <tr>
#       <th id="T_cc053_level0_row3" class="row_heading level0 row3" >700</th>
#       <td id="T_cc053_row3_col0" class="data row3 col0" >59.5</td>
#       <td id="T_cc053_row3_col1" class="data row3 col1" >51.5</td>
#       <td id="T_cc053_row3_col2" class="data row3 col2" >44.7</td>
#       <td id="T_cc053_row3_col3" class="data row3 col3" >38.6</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Annual ROI by share_no vs. dividend</h2>
# <style type="text/css">
# #T_e46ec_row0_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_e46ec_row0_col1, #T_e46ec_row1_col0 {
#   background-color: #a9da6c;
#   color: #000000;
# }
# #T_e46ec_row0_col2 {
#   background-color: #fedc88;
#   color: #000000;
# }
# #T_e46ec_row1_col1 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_e46ec_row1_col2 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_e46ec_row2_col0 {
#   background-color: #fffcba;
#   color: #000000;
# }
# #T_e46ec_row2_col1 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_e46ec_row2_col2 {
#   background-color: #d02927;
#   color: #f1f1f1;
# }
# #T_e46ec_row3_col0 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_e46ec_row3_col1 {
#   background-color: #ec5c3b;
#   color: #f1f1f1;
# }
# #T_e46ec_row3_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e46ec_">
#   <caption>Annual ROI - share_no vs. dividend</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >100</th>
#       <th class="col_heading level0 col1" >200</th>
#       <th class="col_heading level0 col2" >300</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >share_no</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e46ec_level0_row0" class="row_heading level0 row0" >400</th>
#       <td id="T_e46ec_row0_col0" class="data row0 col0" >48.4</td>
#       <td id="T_e46ec_row0_col1" class="data row0 col1" >48.4</td>
#       <td id="T_e46ec_row0_col2" class="data row0 col2" >48.5</td>
#     </tr>
#     <tr>
#       <th id="T_e46ec_level0_row1" class="row_heading level0 row1" >500</th>
#       <td id="T_e46ec_row1_col0" class="data row1 col0" >48.4</td>
#       <td id="T_e46ec_row1_col1" class="data row1 col1" >48.5</td>
#       <td id="T_e46ec_row1_col2" class="data row1 col2" >48.6</td>
#     </tr>
#     <tr>
#       <th id="T_e46ec_level0_row2" class="row_heading level0 row2" >600</th>
#       <td id="T_e46ec_row2_col0" class="data row2 col0" >48.5</td>
#       <td id="T_e46ec_row2_col1" class="data row2 col1" >48.5</td>
#       <td id="T_e46ec_row2_col2" class="data row2 col2" >48.6</td>
#     </tr>
#     <tr>
#       <th id="T_e46ec_level0_row3" class="row_heading level0 row3" >700</th>
#       <td id="T_e46ec_row3_col0" class="data row3 col0" >48.5</td>
#       <td id="T_e46ec_row3_col1" class="data row3 col1" >48.6</td>
#       <td id="T_e46ec_row3_col2" class="data row3 col2" >48.6</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Annual ROI by share_no vs. selling_price</h2>
# <style type="text/css">
# #T_ad119_row0_col0, #T_ad119_row1_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_ad119_row0_col1, #T_ad119_row1_col1, #T_ad119_row2_col1 {
#   background-color: #fedc88;
#   color: #000000;
# }
# #T_ad119_row0_col2, #T_ad119_row1_col2, #T_ad119_row2_col2, #T_ad119_row3_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_ad119_row2_col0, #T_ad119_row3_col0 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_ad119_row3_col1 {
#   background-color: #feda86;
#   color: #000000;
# }
# </style>
# <table id="T_ad119_">
#   <caption>Annual ROI - share_no vs. selling_price</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >100</th>
#       <th class="col_heading level0 col1" >150</th>
#       <th class="col_heading level0 col2" >200</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >share_no</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad119_level0_row0" class="row_heading level0 row0" >400</th>
#       <td id="T_ad119_row0_col0" class="data row0 col0" >34.4</td>
#       <td id="T_ad119_row0_col1" class="data row0 col1" >50.3</td>
#       <td id="T_ad119_row0_col2" class="data row0 col2" >60.6</td>
#     </tr>
#     <tr>
#       <th id="T_ad119_level0_row1" class="row_heading level0 row1" >500</th>
#       <td id="T_ad119_row1_col0" class="data row1 col0" >34.5</td>
#       <td id="T_ad119_row1_col1" class="data row1 col1" >50.4</td>
#       <td id="T_ad119_row1_col2" class="data row1 col2" >60.6</td>
#     </tr>
#     <tr>
#       <th id="T_ad119_level0_row2" class="row_heading level0 row2" >600</th>
#       <td id="T_ad119_row2_col0" class="data row2 col0" >34.6</td>
#       <td id="T_ad119_row2_col1" class="data row2 col1" >50.4</td>
#       <td id="T_ad119_row2_col2" class="data row2 col2" >60.6</td>
#     </tr>
#     <tr>
#       <th id="T_ad119_level0_row3" class="row_heading level0 row3" >700</th>
#       <td id="T_ad119_row3_col0" class="data row3 col0" >34.6</td>
#       <td id="T_ad119_row3_col1" class="data row3 col1" >50.4</td>
#       <td id="T_ad119_row3_col2" class="data row3 col2" >60.7</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Annual ROI by share_no vs. costs</h2>
# <style type="text/css">
# #T_613dc_row0_col0 {
#   background-color: #c41e27;
#   color: #f1f1f1;
# }
# #T_613dc_row0_col1, #T_613dc_row2_col2 {
#   background-color: #f67a49;
#   color: #f1f1f1;
# }
# #T_613dc_row0_col2 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_613dc_row0_col3, #T_613dc_row1_col4, #T_613dc_row2_col5, #T_613dc_row3_col6 {
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_613dc_row0_col4 {
#   background-color: #addc6f;
#   color: #000000;
# }
# #T_613dc_row0_col5 {
#   background-color: #45ad5b;
#   color: #f1f1f1;
# }
# #T_613dc_row0_col6 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_613dc_row1_col0 {
#   background-color: #b71126;
#   color: #f1f1f1;
# }
# #T_613dc_row1_col1 {
#   background-color: #e75337;
#   color: #f1f1f1;
# }
# #T_613dc_row1_col2 {
#   background-color: #fba35c;
#   color: #000000;
# }
# #T_613dc_row1_col3 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_613dc_row1_col5 {
#   background-color: #bde379;
#   color: #000000;
# }
# #T_613dc_row1_col6 {
#   background-color: #73c264;
#   color: #000000;
# }
# #T_613dc_row2_col0 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_613dc_row2_col1 {
#   background-color: #dc3b2c;
#   color: #f1f1f1;
# }
# #T_613dc_row2_col3 {
#   background-color: #fdb96a;
#   color: #000000;
# }
# #T_613dc_row2_col4 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_613dc_row2_col6 {
#   background-color: #c7e77f;
#   color: #000000;
# }
# #T_613dc_row3_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_613dc_row3_col1 {
#   background-color: #d02927;
#   color: #f1f1f1;
# }
# #T_613dc_row3_col2 {
#   background-color: #ed5f3c;
#   color: #f1f1f1;
# }
# #T_613dc_row3_col3 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_613dc_row3_col4 {
#   background-color: #fec877;
#   color: #000000;
# }
# #T_613dc_row3_col5 {
#   background-color: #feeda1;
#   color: #000000;
# }
# </style>
# <table id="T_613dc_">
#   <caption>Annual ROI - share_no vs. costs</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >300</th>
#       <th class="col_heading level0 col1" >400</th>
#       <th class="col_heading level0 col2" >500</th>
#       <th class="col_heading level0 col3" >600</th>
#       <th class="col_heading level0 col4" >700</th>
#       <th class="col_heading level0 col5" >800</th>
#       <th class="col_heading level0 col6" >900</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >share_no</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_613dc_level0_row0" class="row_heading level0 row0" >400</th>
#       <td id="T_613dc_row0_col0" class="data row0 col0" >48.7</td>
#       <td id="T_613dc_row0_col1" class="data row0 col1" >48.6</td>
#       <td id="T_613dc_row0_col2" class="data row0 col2" >48.5</td>
#       <td id="T_613dc_row0_col3" class="data row0 col3" >48.4</td>
#       <td id="T_613dc_row0_col4" class="data row0 col4" >48.4</td>
#       <td id="T_613dc_row0_col5" class="data row0 col5" >48.3</td>
#       <td id="T_613dc_row0_col6" class="data row0 col6" >48.2</td>
#     </tr>
#     <tr>
#       <th id="T_613dc_level0_row1" class="row_heading level0 row1" >500</th>
#       <td id="T_613dc_row1_col0" class="data row1 col0" >48.7</td>
#       <td id="T_613dc_row1_col1" class="data row1 col1" >48.6</td>
#       <td id="T_613dc_row1_col2" class="data row1 col2" >48.6</td>
#       <td id="T_613dc_row1_col3" class="data row1 col3" >48.5</td>
#       <td id="T_613dc_row1_col4" class="data row1 col4" >48.4</td>
#       <td id="T_613dc_row1_col5" class="data row1 col5" >48.4</td>
#       <td id="T_613dc_row1_col6" class="data row1 col6" >48.3</td>
#     </tr>
#     <tr>
#       <th id="T_613dc_level0_row2" class="row_heading level0 row2" >600</th>
#       <td id="T_613dc_row2_col0" class="data row2 col0" >48.7</td>
#       <td id="T_613dc_row2_col1" class="data row2 col1" >48.6</td>
#       <td id="T_613dc_row2_col2" class="data row2 col2" >48.6</td>
#       <td id="T_613dc_row2_col3" class="data row2 col3" >48.5</td>
#       <td id="T_613dc_row2_col4" class="data row2 col4" >48.5</td>
#       <td id="T_613dc_row2_col5" class="data row2 col5" >48.4</td>
#       <td id="T_613dc_row2_col6" class="data row2 col6" >48.4</td>
#     </tr>
#     <tr>
#       <th id="T_613dc_level0_row3" class="row_heading level0 row3" >700</th>
#       <td id="T_613dc_row3_col0" class="data row3 col0" >48.7</td>
#       <td id="T_613dc_row3_col1" class="data row3 col1" >48.6</td>
#       <td id="T_613dc_row3_col2" class="data row3 col2" >48.6</td>
#       <td id="T_613dc_row3_col3" class="data row3 col3" >48.6</td>
#       <td id="T_613dc_row3_col4" class="data row3 col4" >48.5</td>
#       <td id="T_613dc_row3_col5" class="data row3 col5" >48.5</td>
#       <td id="T_613dc_row3_col6" class="data row3 col6" >48.4</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Annual ROI by buying_price vs. dividend</h2>
# <style type="text/css">
# #T_af345_row0_col0 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_af345_row0_col1, #T_af345_row0_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_af345_row1_col0 {
#   background-color: #fed884;
#   color: #000000;
# }
# #T_af345_row1_col1, #T_af345_row1_col2 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_af345_row2_col0 {
#   background-color: #a0d669;
#   color: #000000;
# }
# #T_af345_row2_col1 {
#   background-color: #a2d76a;
#   color: #000000;
# }
# #T_af345_row2_col2 {
#   background-color: #a5d86a;
#   color: #000000;
# }
# #T_af345_row3_col0, #T_af345_row3_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_af345_row3_col2 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_af345_">
#   <caption>Annual ROI - buying_price vs. dividend</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >100</th>
#       <th class="col_heading level0 col1" >200</th>
#       <th class="col_heading level0 col2" >300</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >buying_price</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af345_level0_row0" class="row_heading level0 row0" >40</th>
#       <td id="T_af345_row0_col0" class="data row0 col0" >59.4</td>
#       <td id="T_af345_row0_col1" class="data row0 col1" >59.4</td>
#       <td id="T_af345_row0_col2" class="data row0 col2" >59.5</td>
#     </tr>
#     <tr>
#       <th id="T_af345_level0_row1" class="row_heading level0 row1" >50</th>
#       <td id="T_af345_row1_col0" class="data row1 col0" >51.4</td>
#       <td id="T_af345_row1_col1" class="data row1 col1" >51.5</td>
#       <td id="T_af345_row1_col2" class="data row1 col2" >51.5</td>
#     </tr>
#     <tr>
#       <th id="T_af345_level0_row2" class="row_heading level0 row2" >60</th>
#       <td id="T_af345_row2_col0" class="data row2 col0" >44.6</td>
#       <td id="T_af345_row2_col1" class="data row2 col1" >44.6</td>
#       <td id="T_af345_row2_col2" class="data row2 col2" >44.7</td>
#     </tr>
#     <tr>
#       <th id="T_af345_level0_row3" class="row_heading level0 row3" >70</th>
#       <td id="T_af345_row3_col0" class="data row3 col0" >38.4</td>
#       <td id="T_af345_row3_col1" class="data row3 col1" >38.5</td>
#       <td id="T_af345_row3_col2" class="data row3 col2" >38.6</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Annual ROI by buying_price vs. selling_price</h2>
# <style type="text/css">
# #T_65251_row0_col0 {
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_65251_row0_col1 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_65251_row0_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_65251_row1_col0 {
#   background-color: #abdb6d;
#   color: #000000;
# }
# #T_65251_row1_col1 {
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_65251_row1_col2 {
#   background-color: #e95538;
#   color: #f1f1f1;
# }
# #T_65251_row2_col0 {
#   background-color: #3faa59;
#   color: #f1f1f1;
# }
# #T_65251_row2_col1 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_65251_row2_col2 {
#   background-color: #fcaa5f;
#   color: #000000;
# }
# #T_65251_row3_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_65251_row3_col1 {
#   background-color: #c9e881;
#   color: #000000;
# }
# #T_65251_row3_col2 {
#   background-color: #fee28f;
#   color: #000000;
# }
# </style>
# <table id="T_65251_">
#   <caption>Annual ROI - buying_price vs. selling_price</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >100</th>
#       <th class="col_heading level0 col1" >150</th>
#       <th class="col_heading level0 col2" >200</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >buying_price</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_65251_level0_row0" class="row_heading level0 row0" >40</th>
#       <td id="T_65251_row0_col0" class="data row0 col0" >46.5</td>
#       <td id="T_65251_row0_col1" class="data row0 col1" >61.0</td>
#       <td id="T_65251_row0_col2" class="data row0 col2" >70.9</td>
#     </tr>
#     <tr>
#       <th id="T_65251_level0_row1" class="row_heading level0 row1" >50</th>
#       <td id="T_65251_row1_col0" class="data row1 col0" >38.0</td>
#       <td id="T_65251_row1_col1" class="data row1 col1" >53.2</td>
#       <td id="T_65251_row1_col2" class="data row1 col2" >63.2</td>
#     </tr>
#     <tr>
#       <th id="T_65251_level0_row2" class="row_heading level0 row2" >60</th>
#       <td id="T_65251_row2_col0" class="data row2 col0" >30.4</td>
#       <td id="T_65251_row2_col1" class="data row2 col1" >46.6</td>
#       <td id="T_65251_row2_col2" class="data row2 col2" >56.9</td>
#     </tr>
#     <tr>
#       <th id="T_65251_level0_row3" class="row_heading level0 row3" >70</th>
#       <td id="T_65251_row3_col0" class="data row3 col0" >23.3</td>
#       <td id="T_65251_row3_col1" class="data row3 col1" >40.8</td>
#       <td id="T_65251_row3_col2" class="data row3 col2" >51.5</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Annual ROI by buying_price vs. costs</h2>
# <style type="text/css">
# #T_446a5_row0_col0, #T_446a5_row0_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_446a5_row0_col2, #T_446a5_row0_col3 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_446a5_row0_col4, #T_446a5_row0_col5 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_446a5_row0_col6 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_446a5_row1_col0 {
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_446a5_row1_col1 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_446a5_row1_col2, #T_446a5_row1_col3 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_446a5_row1_col4 {
#   background-color: #fed884;
#   color: #000000;
# }
# #T_446a5_row1_col5, #T_446a5_row1_col6 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_446a5_row2_col0 {
#   background-color: #a9da6c;
#   color: #000000;
# }
# #T_446a5_row2_col1 {
#   background-color: #a7d96b;
#   color: #000000;
# }
# #T_446a5_row2_col2, #T_446a5_row2_col3 {
#   background-color: #a5d86a;
#   color: #000000;
# }
# #T_446a5_row2_col4 {
#   background-color: #a2d76a;
#   color: #000000;
# }
# #T_446a5_row2_col5, #T_446a5_row2_col6 {
#   background-color: #a0d669;
#   color: #000000;
# }
# #T_446a5_row3_col0 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_446a5_row3_col1 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_446a5_row3_col2, #T_446a5_row3_col3 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_446a5_row3_col4 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_446a5_row3_col5, #T_446a5_row3_col6 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_446a5_">
#   <caption>Annual ROI - buying_price vs. costs</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >300</th>
#       <th class="col_heading level0 col1" >400</th>
#       <th class="col_heading level0 col2" >500</th>
#       <th class="col_heading level0 col3" >600</th>
#       <th class="col_heading level0 col4" >700</th>
#       <th class="col_heading level0 col5" >800</th>
#       <th class="col_heading level0 col6" >900</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >buying_price</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_446a5_level0_row0" class="row_heading level0 row0" >40</th>
#       <td id="T_446a5_row0_col0" class="data row0 col0" >59.6</td>
#       <td id="T_446a5_row0_col1" class="data row0 col1" >59.5</td>
#       <td id="T_446a5_row0_col2" class="data row0 col2" >59.5</td>
#       <td id="T_446a5_row0_col3" class="data row0 col3" >59.4</td>
#       <td id="T_446a5_row0_col4" class="data row0 col4" >59.4</td>
#       <td id="T_446a5_row0_col5" class="data row0 col5" >59.3</td>
#       <td id="T_446a5_row0_col6" class="data row0 col6" >59.3</td>
#     </tr>
#     <tr>
#       <th id="T_446a5_level0_row1" class="row_heading level0 row1" >50</th>
#       <td id="T_446a5_row1_col0" class="data row1 col0" >51.6</td>
#       <td id="T_446a5_row1_col1" class="data row1 col1" >51.6</td>
#       <td id="T_446a5_row1_col2" class="data row1 col2" >51.5</td>
#       <td id="T_446a5_row1_col3" class="data row1 col3" >51.5</td>
#       <td id="T_446a5_row1_col4" class="data row1 col4" >51.4</td>
#       <td id="T_446a5_row1_col5" class="data row1 col5" >51.4</td>
#       <td id="T_446a5_row1_col6" class="data row1 col6" >51.3</td>
#     </tr>
#     <tr>
#       <th id="T_446a5_level0_row2" class="row_heading level0 row2" >60</th>
#       <td id="T_446a5_row2_col0" class="data row2 col0" >44.8</td>
#       <td id="T_446a5_row2_col1" class="data row2 col1" >44.8</td>
#       <td id="T_446a5_row2_col2" class="data row2 col2" >44.7</td>
#       <td id="T_446a5_row2_col3" class="data row2 col3" >44.6</td>
#       <td id="T_446a5_row2_col4" class="data row2 col4" >44.6</td>
#       <td id="T_446a5_row2_col5" class="data row2 col5" >44.5</td>
#       <td id="T_446a5_row2_col6" class="data row2 col6" >44.5</td>
#     </tr>
#     <tr>
#       <th id="T_446a5_level0_row3" class="row_heading level0 row3" >70</th>
#       <td id="T_446a5_row3_col0" class="data row3 col0" >38.7</td>
#       <td id="T_446a5_row3_col1" class="data row3 col1" >38.6</td>
#       <td id="T_446a5_row3_col2" class="data row3 col2" >38.6</td>
#       <td id="T_446a5_row3_col3" class="data row3 col3" >38.5</td>
#       <td id="T_446a5_row3_col4" class="data row3 col4" >38.5</td>
#       <td id="T_446a5_row3_col5" class="data row3 col5" >38.4</td>
#       <td id="T_446a5_row3_col6" class="data row3 col6" >38.3</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Annual ROI by dividend vs. selling_price</h2>
# <style type="text/css">
# #T_ee286_row0_col0, #T_ee286_row1_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_ee286_row0_col1, #T_ee286_row1_col1 {
#   background-color: #fedc88;
#   color: #000000;
# }
# #T_ee286_row0_col2, #T_ee286_row1_col2, #T_ee286_row2_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_ee286_row2_col0 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_ee286_row2_col1 {
#   background-color: #feda86;
#   color: #000000;
# }
# </style>
# <table id="T_ee286_">
#   <caption>Annual ROI - dividend vs. selling_price</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >100</th>
#       <th class="col_heading level0 col1" >150</th>
#       <th class="col_heading level0 col2" >200</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dividend</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee286_level0_row0" class="row_heading level0 row0" >100</th>
#       <td id="T_ee286_row0_col0" class="data row0 col0" >34.5</td>
#       <td id="T_ee286_row0_col1" class="data row0 col1" >50.3</td>
#       <td id="T_ee286_row0_col2" class="data row0 col2" >60.6</td>
#     </tr>
#     <tr>
#       <th id="T_ee286_level0_row1" class="row_heading level0 row1" >200</th>
#       <td id="T_ee286_row1_col0" class="data row1 col0" >34.5</td>
#       <td id="T_ee286_row1_col1" class="data row1 col1" >50.4</td>
#       <td id="T_ee286_row1_col2" class="data row1 col2" >60.6</td>
#     </tr>
#     <tr>
#       <th id="T_ee286_level0_row2" class="row_heading level0 row2" >300</th>
#       <td id="T_ee286_row2_col0" class="data row2 col0" >34.6</td>
#       <td id="T_ee286_row2_col1" class="data row2 col1" >50.4</td>
#       <td id="T_ee286_row2_col2" class="data row2 col2" >60.7</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Annual ROI by dividend vs. costs</h2>
# <style type="text/css">
# #T_ed644_row0_col0, #T_ed644_row1_col1, #T_ed644_row2_col2 {
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_ed644_row0_col1, #T_ed644_row1_col2, #T_ed644_row2_col3 {
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_ed644_row0_col2, #T_ed644_row1_col3, #T_ed644_row2_col4 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_ed644_row0_col3, #T_ed644_row1_col4, #T_ed644_row2_col5 {
#   background-color: #cdea83;
#   color: #000000;
# }
# #T_ed644_row0_col4, #T_ed644_row1_col5, #T_ed644_row2_col6 {
#   background-color: #87cb67;
#   color: #000000;
# }
# #T_ed644_row0_col5, #T_ed644_row1_col6 {
#   background-color: #2da155;
#   color: #f1f1f1;
# }
# #T_ed644_row0_col6 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_ed644_row1_col0, #T_ed644_row2_col1 {
#   background-color: #dd3d2d;
#   color: #f1f1f1;
# }
# #T_ed644_row2_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ed644_">
#   <caption>Annual ROI - dividend vs. costs</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >300</th>
#       <th class="col_heading level0 col1" >400</th>
#       <th class="col_heading level0 col2" >500</th>
#       <th class="col_heading level0 col3" >600</th>
#       <th class="col_heading level0 col4" >700</th>
#       <th class="col_heading level0 col5" >800</th>
#       <th class="col_heading level0 col6" >900</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dividend</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ed644_level0_row0" class="row_heading level0 row0" >100</th>
#       <td id="T_ed644_row0_col0" class="data row0 col0" >48.6</td>
#       <td id="T_ed644_row0_col1" class="data row0 col1" >48.6</td>
#       <td id="T_ed644_row0_col2" class="data row0 col2" >48.5</td>
#       <td id="T_ed644_row0_col3" class="data row0 col3" >48.5</td>
#       <td id="T_ed644_row0_col4" class="data row0 col4" >48.4</td>
#       <td id="T_ed644_row0_col5" class="data row0 col5" >48.4</td>
#       <td id="T_ed644_row0_col6" class="data row0 col6" >48.3</td>
#     </tr>
#     <tr>
#       <th id="T_ed644_level0_row1" class="row_heading level0 row1" >200</th>
#       <td id="T_ed644_row1_col0" class="data row1 col0" >48.7</td>
#       <td id="T_ed644_row1_col1" class="data row1 col1" >48.6</td>
#       <td id="T_ed644_row1_col2" class="data row1 col2" >48.6</td>
#       <td id="T_ed644_row1_col3" class="data row1 col3" >48.5</td>
#       <td id="T_ed644_row1_col4" class="data row1 col4" >48.5</td>
#       <td id="T_ed644_row1_col5" class="data row1 col5" >48.4</td>
#       <td id="T_ed644_row1_col6" class="data row1 col6" >48.4</td>
#     </tr>
#     <tr>
#       <th id="T_ed644_level0_row2" class="row_heading level0 row2" >300</th>
#       <td id="T_ed644_row2_col0" class="data row2 col0" >48.7</td>
#       <td id="T_ed644_row2_col1" class="data row2 col1" >48.7</td>
#       <td id="T_ed644_row2_col2" class="data row2 col2" >48.6</td>
#       <td id="T_ed644_row2_col3" class="data row2 col3" >48.6</td>
#       <td id="T_ed644_row2_col4" class="data row2 col4" >48.5</td>
#       <td id="T_ed644_row2_col5" class="data row2 col5" >48.5</td>
#       <td id="T_ed644_row2_col6" class="data row2 col6" >48.4</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Annual ROI by selling_price vs. costs</h2>
# <style type="text/css">
# #T_be802_row0_col0 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_be802_row0_col1, #T_be802_row0_col2 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_be802_row0_col3 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_be802_row0_col4 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_be802_row0_col5, #T_be802_row0_col6 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_be802_row1_col0 {
#   background-color: #fed884;
#   color: #000000;
# }
# #T_be802_row1_col1, #T_be802_row1_col2 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_be802_row1_col3, #T_be802_row1_col4 {
#   background-color: #fedc88;
#   color: #000000;
# }
# #T_be802_row1_col5, #T_be802_row1_col6 {
#   background-color: #fede89;
#   color: #000000;
# }
# #T_be802_row2_col0, #T_be802_row2_col1, #T_be802_row2_col2, #T_be802_row2_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_be802_row2_col4, #T_be802_row2_col5, #T_be802_row2_col6 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_be802_">
#   <caption>Annual ROI - selling_price vs. costs</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >300</th>
#       <th class="col_heading level0 col1" >400</th>
#       <th class="col_heading level0 col2" >500</th>
#       <th class="col_heading level0 col3" >600</th>
#       <th class="col_heading level0 col4" >700</th>
#       <th class="col_heading level0 col5" >800</th>
#       <th class="col_heading level0 col6" >900</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >selling_price</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be802_level0_row0" class="row_heading level0 row0" >100</th>
#       <td id="T_be802_row0_col0" class="data row0 col0" >34.8</td>
#       <td id="T_be802_row0_col1" class="data row0 col1" >34.7</td>
#       <td id="T_be802_row0_col2" class="data row0 col2" >34.6</td>
#       <td id="T_be802_row0_col3" class="data row0 col3" >34.5</td>
#       <td id="T_be802_row0_col4" class="data row0 col4" >34.5</td>
#       <td id="T_be802_row0_col5" class="data row0 col5" >34.4</td>
#       <td id="T_be802_row0_col6" class="data row0 col6" >34.3</td>
#     </tr>
#     <tr>
#       <th id="T_be802_level0_row1" class="row_heading level0 row1" >150</th>
#       <td id="T_be802_row1_col0" class="data row1 col0" >50.5</td>
#       <td id="T_be802_row1_col1" class="data row1 col1" >50.5</td>
#       <td id="T_be802_row1_col2" class="data row1 col2" >50.4</td>
#       <td id="T_be802_row1_col3" class="data row1 col3" >50.4</td>
#       <td id="T_be802_row1_col4" class="data row1 col4" >50.3</td>
#       <td id="T_be802_row1_col5" class="data row1 col5" >50.3</td>
#       <td id="T_be802_row1_col6" class="data row1 col6" >50.2</td>
#     </tr>
#     <tr>
#       <th id="T_be802_level0_row2" class="row_heading level0 row2" >200</th>
#       <td id="T_be802_row2_col0" class="data row2 col0" >60.7</td>
#       <td id="T_be802_row2_col1" class="data row2 col1" >60.7</td>
#       <td id="T_be802_row2_col2" class="data row2 col2" >60.7</td>
#       <td id="T_be802_row2_col3" class="data row2 col3" >60.6</td>
#       <td id="T_be802_row2_col4" class="data row2 col4" >60.6</td>
#       <td id="T_be802_row2_col5" class="data row2 col5" >60.6</td>
#       <td id="T_be802_row2_col6" class="data row2 col6" >60.5</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 8. Identify best-case investment scenario

# %%
@dataclass
class ModelInputs:
    share_no : int = 600
    buying_price: int = 20
    dividend: int = 800
    selling_price: int = 22
    costs: int = 100
        
model_data = ModelInputs()
model_data
# Out:
# ModelInputs(share_no=600, buying_price=20, dividend=800, selling_price=22, costs=100)

# %%
def annualised_roi_per_year_for_required_roi(data: ModelInputs):
    year = 0
    prior_roi = 0
    
    for year in range(19):
        year = year + 1        
        net_return = (data.selling_price - data.buying_price) \
        * data.share_no + data.dividend - data.costs
        cost_of_investment = data.buying_price * data.share_no

        roi = prior_roi + ((net_return) / (cost_of_investment)) * 100 
        annual_roi = ((1 + (roi / 100)) ** (1 / year) - 1) * 100
        
        prior_roi = roi 
    print(f'The annualised ROI at year {year} reaches {annual_roi}% \
for total shares of {model_data.share_no} with a buying price of \
{model_data.buying_price}, selling price of {model_data.selling_price}')
    
annualised_roi_per_year_for_required_roi(model_data)
# Out:
# The annualised ROI at year 19 reaches 7.580841850996478% for total shares of 600 with a buying price of 20, selling price of 22
