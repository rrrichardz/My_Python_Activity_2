# %% [markdown]
# ### LSE Data Analytics Online Career Accelerator
#
# # DA301:  Advanced Analytics for Organisational Impact

# %% [markdown]
# # Vision Zero road safety survey analysis
#
# This notebook looks at responses to a survey about road safety. The ultimate objective of the data anaysis is to improve driver, pedestrian, and bicyclist transportation safety. What can we extract from the comments left by the respondents that can help us better understand the current sentiment towards road safety? Could we perhaps find any strong indication where improvements need to be made?

# %%
# Import libraries.
import numpy as np
import pandas as pd

import warnings # Note: Indicates situations that aren't necessarily exceptions.
warnings.filterwarnings('ignore') # Filter out any warning messages.
# Import data.
survey_data = pd.read_csv("Vision_Zero_Safety.csv")

# View the data.
print(survey_data.shape)
survey_data.head()
# Out:
# (5591, 11)
#            X          Y  OBJECTID                                GLOBALID  \
# 0 -77.020315  38.892890         1  {7AA2347A-C035-4D5A-9196-07C309B4C7BF}
# 1 -77.020877  38.893046         2  {1AFF4069-5D94-49A1-9D1F-0A089D414F5F}
# 2 -77.024643  38.918125         3  {908CCF07-A389-40EE-B5D2-7ADAF90404D1}
# 3 -77.003515  38.896124         4  {12E7A594-76F9-41CE-91AC-9B6B8E08EC5C}
# 4 -77.017562  38.883266         5  {0AED48A8-A4DD-44E9-8C4A-D45E14E7462D}
#
#   REQUESTID    USERTYPE               REQUESTTYPE             REQUESTDATE  \
# 0         1  Pedestrian    Blocking the crosswalk  2015/06/29 19:56:00+00
# 1         2  Pedestrian       Other Driving Issue  2015/06/29 19:57:36+00
# 2         3  Pedestrian  Not enough time to cross  2015/06/29 20:14:32+00
# 3         4  Pedestrian         Stop sign running  2015/06/29 20:15:02+00
# 4         5       Biker          Cyclist behavior  2015/06/29 20:15:05+00
#
#        STATUS  STREETSEGID                                           COMMENTS
# 0  Unassigned      10022.0  Cars for valet at the Capital Grille constantl...
# 1  Unassigned      10022.0                               Illegal U-Turns here
# 2  Unassigned      10396.0  There is no walk sign on this intersection so ...
# 3  Unassigned       4381.0  Constant issue; MPD never enforces despite rep...
# 4  Unassigned       5344.0             Some cyclists often run this red light

# %% [markdown]
# ## 1. Pre-process the data

# %% [markdown]
# ### Drop rows from the table that do not have any value for their COMMENTS field

# %%
survey_data.dropna(subset = ['COMMENTS'], inplace = True)
survey_data.shape
# Out:
# (4940, 11)

# %% [markdown]
# ### Change all the words in the comments to lower case

# %%
# Transform data to lowercase.
survey_data['COMMENTS'] = survey_data['COMMENTS'].apply(lambda x: " ".join(x.lower() for x in x.split()))

# Preview the results.
survey_data['COMMENTS'].head()
# Out:
# 0    cars for valet at the capital grille constantl...
# 1                                 illegal u-turns here
# 2    there is no walk sign on this intersection so ...
# 3    constant issue; mpd never enforces despite rep...
# 4               some cyclists often run this red light
# Name: COMMENTS, dtype: object

# %% [markdown]
# ### Remove punctuation

# %%
survey_data['COMMENTS'] = survey_data['COMMENTS'].str.replace('[^\w\s]','')
survey_data['COMMENTS'].head()
# Out:
# 0    cars for valet at the capital grille constantl...
# 1                                  illegal uturns here
# 2    there is no walk sign on this intersection so ...
# 3    constant issue mpd never enforces despite repe...
# 4               some cyclists often run this red light
# Name: COMMENTS, dtype: object

# %% [markdown]
# ### Drop duplicates from the COMMENTS column

# %%
# Check the number of duplicate values in the COMMENTS column.
survey_data.COMMENTS.duplicated().sum()
# Out:
# 282

# %%
# Drop duplicates.
survey = survey_data.drop_duplicates(subset = ['COMMENTS'])

# %%
# Preview data.
survey.reset_index(inplace = True)
survey.head()
# Out:
#    index          X          Y  OBJECTID  \
# 0      0 -77.020315  38.892890         1
# 1      1 -77.020877  38.893046         2
# 2      2 -77.024643  38.918125         3
# 3      3 -77.003515  38.896124         4
# 4      4 -77.017562  38.883266         5
#
#                                  GLOBALID REQUESTID    USERTYPE  \
# 0  {7AA2347A-C035-4D5A-9196-07C309B4C7BF}         1  Pedestrian
# 1  {1AFF4069-5D94-49A1-9D1F-0A089D414F5F}         2  Pedestrian
# 2  {908CCF07-A389-40EE-B5D2-7ADAF90404D1}         3  Pedestrian
# 3  {12E7A594-76F9-41CE-91AC-9B6B8E08EC5C}         4  Pedestrian
# 4  {0AED48A8-A4DD-44E9-8C4A-D45E14E7462D}         5       Biker
#
#                 REQUESTTYPE             REQUESTDATE      STATUS  STREETSEGID  \
# 0    Blocking the crosswalk  2015/06/29 19:56:00+00  Unassigned      10022.0
# 1       Other Driving Issue  2015/06/29 19:57:36+00  Unassigned      10022.0
# 2  Not enough time to cross  2015/06/29 20:14:32+00  Unassigned      10396.0
# 3         Stop sign running  2015/06/29 20:15:02+00  Unassigned       4381.0
# 4          Cyclist behavior  2015/06/29 20:15:05+00  Unassigned       5344.0
#
#                                             COMMENTS
# 0  cars for valet at the capital grille constantl...
# 1                                illegal uturns here
# 2  there is no walk sign on this intersection so ...
# 3  constant issue mpd never enforces despite repe...
# 4             some cyclists often run this red light

# %%
survey.shape
# Out:
# (4658, 12)

# %% [markdown]
# As we can see that the rows with empty fields and the duplicate entries in the COMMENTS column have been removed from the dataframe.

# %% [markdown]
# ## 2. Visualise the most frequently used words

# %%
# String all the comments together in a single variable.
all_comments = ''
for i in range(survey.shape[0]):
    # Add each comment.
    all_comments = all_comments + survey['COMMENTS'][i]

# %%
# Import along with matplotlib and seaborn for visualisation.
from wordcloud import WordCloud 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# Set the colour palette.
sns.set(color_codes = True)

# Create a WordCloud object.
wordcloud = WordCloud(width = 1600, height = 900, 
                background_color = 'white',
                colormap = 'plasma', 
                stopwords = 'none',
                min_font_size = 10).generate(all_comments) 
  
# Plot the WordCloud image.                       
plt.figure(figsize = (16, 9), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %% [markdown]
# ## 3. Find the most frequently used words with tokenisation

# %%
# Import nltk and download nltk's resources to assist with tokenisation.
import nltk

nltk.download('punkt')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\richa\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ### Tokenisation

# %%
# Tokenise the words.
survey['tokens'] = survey['COMMENTS'].apply(word_tokenize)
# Preview the results.
survey['tokens'].head()
# Out:
# 0    [cars, for, valet, at, the, capital, grille, c...
# 1                              [illegal, uturns, here]
# 2    [there, is, no, walk, sign, on, this, intersec...
# 3    [constant, issue, mpd, never, enforces, despit...
# 4       [some, cyclists, often, run, this, red, light]
# Name: tokens, dtype: object

# %%
# Combine all tokens into one list.
all_tokens = []
for i in range(survey.shape[0]):
    all_tokens = all_tokens + survey['tokens'][i]

# %%
# Compute the tokens with the maximum frequency.
from nltk.probability import FreqDist
# Calculate the frequency distribution.
fdist = FreqDist(all_tokens)
fdist
# Out:
# FreqDist({'the': 5567, 'to': 4358, 'and': 3122, 'a': 2298, 'on': 2161, 'is': 1999, 'of': 1908, 'cars': 1856, 'this': 1698, 'for': 1517, ...})

# %%
# Filter out tokens that are neither alphabets or numbers.
# (to eliminate punctuation marks etc)
tokens1 = [word for word in all_tokens if word.isalnum()]

# %% [markdown]
# ### Eliminate stopwords

# %%
# Download the nltk resource, import the method, and extract stopwords in the English language.
nltk.download ('stopwords')
from nltk.corpus import stopwords

# Create a set of Enligsh stop words.
english_stopwords = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\richa\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Create a list of tokens without stop words.
tokens2 = [x for x in tokens1 if x.lower() not in english_stopwords]

# %%
# Define an empty string variable.
tokens2_string = ''
for value in tokens2:
    # Add each filtered token word to the string.
    tokens2_string = tokens2_string + value + ' '

# %% [markdown]
# ### Visualise the tokens of relevance in a word cloud

# %%
# Create a word cloud object.
wordcloud = WordCloud(width = 1600, height = 900, 
                background_color = 'white', 
                colormap = 'plasma', 
                min_font_size = 10).generate(tokens2_string) 

# Plot the WordCloud image                        
plt.figure(figsize = (16, 9), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %% [markdown]
# ## 4. Count the top 15 words that appear most often

# %%
# View the frequency distribution.
fdist1 = FreqDist(tokens2)
fdist1
# Out:
# FreqDist({'cars': 1856, 'pedestrians': 1143, 'street': 1056, 'drivers': 1009, 'lane': 992, 'stop': 983, 'traffic': 976, 'bike': 817, 'intersection': 810, 'light': 797, ...})

# %%
'''top 15 commonly used words across the comments.'''
# Import Counter.
from collections import Counter

# Generate DF out of Counter.
counts = pd.DataFrame(Counter(tokens2).most_common(15),
                      columns = ['Word', 'Frequency']).set_index('Word')
# Display the result.
counts
# Out:
#               Frequency
# Word
# cars               1856
# pedestrians        1143
# street             1056
# drivers            1009
# lane                992
# stop                983
# traffic             976
# bike                817
# intersection        810
# light               797
# st                  749
# cross               712
# crosswalk           613
# turn                609
# speed               570

# %%
# Generate bar graph.
# Set the plot type.
ax = counts.plot(kind = 'barh', figsize = (16, 9), fontsize = 12,
                 colormap = 'plasma')
# Set the labels.
ax.set_xlabel("Count", fontsize = 12)
ax.set_ylabel("Word", fontsize = 12)
ax.set_title("Safety survey responses: Count of the 15 most frequent words",
             fontsize = 20)

# Add annotations.
for i in ax.patches:
    ax.text(i.get_width() + .41, i.get_y() + .1, str(round((i.get_width()), 2)),
            fontsize = 12, color = 'red')

# %% [markdown]
# ## Estimate sentiment in comments: examples

# %%
# Install TextBlob.
# !pip install textblob

# Import library.
from textblob import TextBlob
# Out:
# Collecting textblob
#   Downloading textblob-0.17.1-py2.py3-none-any.whl (636 kB)
# Requirement already satisfied: nltk>=3.1 in c:\users\richa\anaconda3\lib\site-packages (from textblob) (3.6.5)
# Requirement already satisfied: click in c:\users\richa\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (8.0.3)
# Requirement already satisfied: joblib in c:\users\richa\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\richa\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (2021.8.3)
# Requirement already satisfied: tqdm in c:\users\richa\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (4.62.3)
# Requirement already satisfied: colorama in c:\users\richa\anaconda3\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.4)
# Installing collected packages: textblob
# Successfully installed textblob-0.17.1

# %% [markdown]
# ### Test the TextBlod library

# %%
TextBlob("My cute little pet mouse loves to eat from my hand, I love how it tickles").sentiment
# Out:
# Sentiment(polarity=0.2708333333333333, subjectivity=0.7000000000000001)

# %%
TextBlob("That awful rodent got into the garden shed and destroyed everything").sentiment
# Out:
# Sentiment(polarity=-1.0, subjectivity=1.0)

# %%
TextBlob("The original cartoon version is better but the film has some good scenes").sentiment
# Out:
# Sentiment(polarity=0.525, subjectivity=0.6166666666666667)

# %% [markdown]
# ## Extract polarity and subjectivity from survey comments

# %%
# [1] Define a function to extract a polarity score for the comment.
def generate_polarity(comment):
    return TextBlob(comment).sentiment[0]

# [2] Populate a new column with polarity scores for each comment.
survey['polarity'] = survey['COMMENTS'].apply(generate_polarity)

# [3] Preview the results.
survey['polarity'].head()
# Out:
# 0    0.000000
# 1   -0.500000
# 2    0.233333
# 3    0.000000
# 4    0.200000
# Name: polarity, dtype: float64

# %%
# [1] Define a function to extract a subjectivity score for the comments.
def generate_subjectivity(comment):
    return TextBlob(comment).sentiment[1]

# [2] Populate a new column with subjectivity scores for each comment.
survey['subjectivity'] = survey['COMMENTS'].apply(generate_subjectivity)

# [3] Preview the results.
survey['subjectivity'].head()
# Out:
# 0    0.333333
# 1    0.500000
# 2    0.500000
# 3    0.333333
# 4    0.350000
# Name: subjectivity, dtype: float64

# %% [markdown]
# ## Visualise sentiment polarity scores on a histogram

# %%
# Set the number of bins.
num_bins = 25

# Set the plot area.
plt.figure(figsize = (16, 9))

# Define the bars.
n, bins, patches = plt.hist(survey['polarity'], num_bins, facecolor = 'red',
                           alpha = 0.6)

# Set the labels.
plt.xlabel('Polarity', fontsize = 12)
plt.ylabel('Count', fontsize = 12)
plt.title('Histogram of sentiment score polarity', fontsize = 12)

plt.show()

# %% [markdown]
# ## Extract contextualised comments

# %%
# [1] Create a DataFrame.
positive_sentiment = survey.nlargest(10, 'polarity')

# [2] Eliminate unnecessary columns.
positive_sentiment = positive_sentiment[['COMMENTS', 'USERTYPE', 'polarity',
                                       'subjectivity', 'STREETSEGID']]

# [3] Adjust the column width.
positive_sentiment.style.set_properties(subset = ['COMMENTS'], **{'width': '1200px'})
# Out:
# <style type="text/css">
# #T_86675_row0_col0, #T_86675_row1_col0, #T_86675_row2_col0, #T_86675_row3_col0, #T_86675_row4_col0, #T_86675_row5_col0, #T_86675_row6_col0, #T_86675_row7_col0, #T_86675_row8_col0, #T_86675_row9_col0 {
#   width: 1200px;
# }
# </style>
# <table id="T_86675_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >COMMENTS</th>
#       <th class="col_heading level0 col1" >USERTYPE</th>
#       <th class="col_heading level0 col2" >polarity</th>
#       <th class="col_heading level0 col3" >subjectivity</th>
#       <th class="col_heading level0 col4" >STREETSEGID</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86675_level0_row0" class="row_heading level0 row0" >2467</th>
#       <td id="T_86675_row0_col0" class="data row0 col0" >this would be an excellent place to divert throughtraffic from 6th avenue on to nj prohibiting cars from traveling southbound with a diverter would create a neighborhood street like 5th this would make room for a southbound separated bike lane</td>
#       <td id="T_86675_row0_col1" class="data row0 col1" >Pedestrian</td>
#       <td id="T_86675_row0_col2" class="data row0 col2" >1.000000</td>
#       <td id="T_86675_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_86675_row0_col4" class="data row0 col4" >4658.000000</td>
#     </tr>
#     <tr>
#       <th id="T_86675_level0_row1" class="row_heading level0 row1" >2552</th>
#       <td id="T_86675_row1_col0" class="data row1 col0" >legalize eb biking towards ria ne this portion of newton is 1way wb plenty of space for contraflow lane this is best connection to s portion of mt rainier and points e should be accompanied by protected bike lane on ria ne to eastern</td>
#       <td id="T_86675_row1_col1" class="data row1 col1" >Biker</td>
#       <td id="T_86675_row1_col2" class="data row1 col2" >1.000000</td>
#       <td id="T_86675_row1_col3" class="data row1 col3" >0.300000</td>
#       <td id="T_86675_row1_col4" class="data row1 col4" >3644.000000</td>
#     </tr>
#     <tr>
#       <th id="T_86675_level0_row2" class="row_heading level0 row2" >2276</th>
#       <td id="T_86675_row2_col0" class="data row2 col0" >southbound traffic doesnt get very good visibility of peds coming from dahlia intersection because of the angle of the street and lighttolight driving encourages distraction</td>
#       <td id="T_86675_row2_col1" class="data row2 col1" >Pedestrian</td>
#       <td id="T_86675_row2_col2" class="data row2 col2" >0.910000</td>
#       <td id="T_86675_row2_col3" class="data row2 col3" >0.780000</td>
#       <td id="T_86675_row2_col4" class="data row2 col4" >1813.000000</td>
#     </tr>
#     <tr>
#       <th id="T_86675_level0_row3" class="row_heading level0 row3" >2850</th>
#       <td id="T_86675_row3_col0" class="data row3 col0" >cars run the stop signs at this intersection traffic calming measures requested raised crosswalks would be ideal which would require motorist to stop</td>
#       <td id="T_86675_row3_col1" class="data row3 col1" >Pedestrian</td>
#       <td id="T_86675_row3_col2" class="data row3 col2" >0.900000</td>
#       <td id="T_86675_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_86675_row3_col4" class="data row3 col4" >9526.000000</td>
#     </tr>
#     <tr>
#       <th id="T_86675_level0_row4" class="row_heading level0 row4" >3590</th>
#       <td id="T_86675_row4_col0" class="data row4 col0" >too often peds are walking through the bike lane on 15th without recognition that bikes are coming creating a safety issue the nyc look campaign would be ideal for this corridor</td>
#       <td id="T_86675_row4_col1" class="data row4 col1" >Biker</td>
#       <td id="T_86675_row4_col2" class="data row4 col2" >0.900000</td>
#       <td id="T_86675_row4_col3" class="data row4 col3" >1.000000</td>
#       <td id="T_86675_row4_col4" class="data row4 col4" >189.000000</td>
#     </tr>
#     <tr>
#       <th id="T_86675_level0_row5" class="row_heading level0 row5" >688</th>
#       <td id="T_86675_row5_col0" class="data row5 col0" >would be really great if the bikes lanes on kansas would continue southwest of georgia ave</td>
#       <td id="T_86675_row5_col1" class="data row5 col1" >Biker</td>
#       <td id="T_86675_row5_col2" class="data row5 col2" >0.800000</td>
#       <td id="T_86675_row5_col3" class="data row5 col3" >0.750000</td>
#       <td id="T_86675_row5_col4" class="data row5 col4" >7063.000000</td>
#     </tr>
#     <tr>
#       <th id="T_86675_level0_row6" class="row_heading level0 row6" >1280</th>
#       <td id="T_86675_row6_col0" class="data row6 col0" >pedestrians in the crosswalk are at great danger here since cars will not stop</td>
#       <td id="T_86675_row6_col1" class="data row6 col1" >Pedestrian</td>
#       <td id="T_86675_row6_col2" class="data row6 col2" >0.800000</td>
#       <td id="T_86675_row6_col3" class="data row6 col3" >0.750000</td>
#       <td id="T_86675_row6_col4" class="data row6 col4" >12927.000000</td>
#     </tr>
#     <tr>
#       <th id="T_86675_level0_row7" class="row_heading level0 row7" >1946</th>
#       <td id="T_86675_row7_col0" class="data row7 col0" >drivers often fly through this intersection without stopping making it unsafe for everyone</td>
#       <td id="T_86675_row7_col1" class="data row7 col1" >Car Driver</td>
#       <td id="T_86675_row7_col2" class="data row7 col2" >0.800000</td>
#       <td id="T_86675_row7_col3" class="data row7 col3" >0.900000</td>
#       <td id="T_86675_row7_col4" class="data row7 col4" >11743.000000</td>
#     </tr>
#     <tr>
#       <th id="T_86675_level0_row8" class="row_heading level0 row8" >2188</th>
#       <td id="T_86675_row8_col0" class="data row8 col0" >would be great if there were some way to encourage the cemetery to create pedestrian connections here</td>
#       <td id="T_86675_row8_col1" class="data row8 col1" >Pedestrian</td>
#       <td id="T_86675_row8_col2" class="data row8 col2" >0.800000</td>
#       <td id="T_86675_row8_col3" class="data row8 col3" >0.750000</td>
#       <td id="T_86675_row8_col4" class="data row8 col4" >3705.000000</td>
#     </tr>
#     <tr>
#       <th id="T_86675_level0_row9" class="row_heading level0 row9" >2424</th>
#       <td id="T_86675_row9_col0" class="data row9 col0" >cycle track on wisconsin would make for a great ns commuting corridor  there are plenty of car lanes</td>
#       <td id="T_86675_row9_col1" class="data row9 col1" >Biker</td>
#       <td id="T_86675_row9_col2" class="data row9 col2" >0.800000</td>
#       <td id="T_86675_row9_col3" class="data row9 col3" >0.750000</td>
#       <td id="T_86675_row9_col4" class="data row9 col4" >2593.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
positive_sentiment.at[1946, 'COMMENTS']
# Out:
# 'drivers often fly through this intersection without stopping making it unsafe for everyone'

# %%
# Create a DataFrame.
negative_sentiment = survey.nsmallest(10, 'polarity')

# Eliminate unnecessary columns.
negative_sentiment = negative_sentiment[['COMMENTS', 'USERTYPE', 'polarity',
                                        'STREETSEGID']]

# Adjust the column width.
negative_sentiment.style.set_properties(subset = ['COMMENTS'], **{'width': '1200px'})
# Out:
# <style type="text/css">
# #T_e8b2d_row0_col0, #T_e8b2d_row1_col0, #T_e8b2d_row2_col0, #T_e8b2d_row3_col0, #T_e8b2d_row4_col0, #T_e8b2d_row5_col0, #T_e8b2d_row6_col0, #T_e8b2d_row7_col0, #T_e8b2d_row8_col0, #T_e8b2d_row9_col0 {
#   width: 1200px;
# }
# </style>
# <table id="T_e8b2d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >COMMENTS</th>
#       <th class="col_heading level0 col1" >USERTYPE</th>
#       <th class="col_heading level0 col2" >polarity</th>
#       <th class="col_heading level0 col3" >STREETSEGID</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8b2d_level0_row0" class="row_heading level0 row0" >737</th>
#       <td id="T_e8b2d_row0_col0" class="data row0 col0" >cars routinely ignore this stop sign a camera would catch some of the worst violators</td>
#       <td id="T_e8b2d_row0_col1" class="data row0 col1" >Pedestrian</td>
#       <td id="T_e8b2d_row0_col2" class="data row0 col2" >-1.000000</td>
#       <td id="T_e8b2d_row0_col3" class="data row0 col3" >14572.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e8b2d_level0_row1" class="row_heading level0 row1" >1250</th>
#       <td id="T_e8b2d_row1_col0" class="data row1 col0" >cars speed through here and dont stop for pedestrians in the crosswalk especially bad at rush hour</td>
#       <td id="T_e8b2d_row1_col1" class="data row1 col1" >Pedestrian</td>
#       <td id="T_e8b2d_row1_col2" class="data row1 col2" >-1.000000</td>
#       <td id="T_e8b2d_row1_col3" class="data row1 col3" >4131.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e8b2d_level0_row2" class="row_heading level0 row2" >1268</th>
#       <td id="T_e8b2d_row2_col0" class="data row2 col0" >this intersection is one of the worst in the city traffic from all angles  eckington pl ny ave fl ave  are routinely backed up and cause congestion for pedestrians drivers and cyclists at this intersection a traffic study would be helpful</td>
#       <td id="T_e8b2d_row2_col1" class="data row2 col1" >Pedestrian</td>
#       <td id="T_e8b2d_row2_col2" class="data row2 col2" >-1.000000</td>
#       <td id="T_e8b2d_row2_col3" class="data row2 col3" >5256.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e8b2d_level0_row3" class="row_heading level0 row3" >1506</th>
#       <td id="T_e8b2d_row3_col0" class="data row3 col0" >motorists scream through this stretch which is terrifying if you are crossing the road in the crosswalk</td>
#       <td id="T_e8b2d_row3_col1" class="data row3 col1" >Pedestrian</td>
#       <td id="T_e8b2d_row3_col2" class="data row3 col2" >-1.000000</td>
#       <td id="T_e8b2d_row3_col3" class="data row3 col3" >10095.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e8b2d_level0_row4" class="row_heading level0 row4" >2207</th>
#       <td id="T_e8b2d_row4_col0" class="data row4 col0" >this is the worst stretch of pennsylvania for cars speeding this is the section that they get to maximum speed</td>
#       <td id="T_e8b2d_row4_col1" class="data row4 col1" >Biker</td>
#       <td id="T_e8b2d_row4_col2" class="data row4 col2" >-1.000000</td>
#       <td id="T_e8b2d_row4_col3" class="data row4 col3" >10736.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e8b2d_level0_row5" class="row_heading level0 row5" >2491</th>
#       <td id="T_e8b2d_row5_col0" class="data row5 col0" >the road is always in terrible conditions causing people to swerve into oncoming traffic in order to avoid potholes</td>
#       <td id="T_e8b2d_row5_col1" class="data row5 col1" >Car Driver</td>
#       <td id="T_e8b2d_row5_col2" class="data row5 col2" >-1.000000</td>
#       <td id="T_e8b2d_row5_col3" class="data row5 col3" >7812.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e8b2d_level0_row6" class="row_heading level0 row6" >2526</th>
#       <td id="T_e8b2d_row6_col0" class="data row6 col0" >please please please install allway stop here driver never stop and it is terrifying</td>
#       <td id="T_e8b2d_row6_col1" class="data row6 col1" >Pedestrian</td>
#       <td id="T_e8b2d_row6_col2" class="data row6 col2" >-1.000000</td>
#       <td id="T_e8b2d_row6_col3" class="data row6 col3" >13058.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e8b2d_level0_row7" class="row_heading level0 row7" >2891</th>
#       <td id="T_e8b2d_row7_col0" class="data row7 col0" >jaywalking terrible in this area</td>
#       <td id="T_e8b2d_row7_col1" class="data row7 col1" >Car Driver</td>
#       <td id="T_e8b2d_row7_col2" class="data row7 col2" >-1.000000</td>
#       <td id="T_e8b2d_row7_col3" class="data row7 col3" >7244.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e8b2d_level0_row8" class="row_heading level0 row8" >2897</th>
#       <td id="T_e8b2d_row8_col0" class="data row8 col0" >bike lanes in terrible shape please repair</td>
#       <td id="T_e8b2d_row8_col1" class="data row8 col1" >Car Driver</td>
#       <td id="T_e8b2d_row8_col2" class="data row8 col2" >-1.000000</td>
#       <td id="T_e8b2d_row8_col3" class="data row8 col3" >3265.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e8b2d_level0_row9" class="row_heading level0 row9" >3171</th>
#       <td id="T_e8b2d_row9_col0" class="data row9 col0" >motorcyclists and scooterriders ride in the bike lane they are the worst</td>
#       <td id="T_e8b2d_row9_col1" class="data row9 col1" >Biker</td>
#       <td id="T_e8b2d_row9_col2" class="data row9 col2" >-1.000000</td>
#       <td id="T_e8b2d_row9_col3" class="data row9 col3" >10571.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
negative_sentiment.at[2207, 'COMMENTS']
# Out:
# 'this is the worst stretch of pennsylvania for cars speeding this is the section that they get to maximum speed'

# %% [markdown]
# ## Identify named entities

# %%
# Install spaCy.
# !pip install -U pip setuptools wheel
# !pip install -U spacy
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: pip in c:\users\richa\anaconda3\lib\site-packages (21.2.4)
# Collecting pip
#   Downloading pip-22.1.2-py3-none-any.whl (2.1 MB)
# Requirement already satisfied: setuptools in c:\users\richa\anaconda3\lib\site-packages (58.0.4)
# Collecting setuptools
#   Downloading setuptools-62.3.2-py3-none-any.whl (1.2 MB)
# Requirement already satisfied: wheel in c:\users\richa\anaconda3\lib\site-packages (0.37.0)
# Collecting wheel
#   Downloading wheel-0.37.1-py2.py3-none-any.whl (35 kB)
# Installing collected packages: wheel, setuptools, pip
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.37.0
#     Uninstalling wheel-0.37.0:
#       Successfully uninstalled wheel-0.37.0
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 58.0.4
#     Uninstalling setuptools-58.0.4:
#       Successfully uninstalled setuptools-58.0.4
#   Attempting uninstall: pip
#     Found existing installation: pip 21.2.4
#     Uninstalling pip-21.2.4:
#       Successfully uninstalled pip-21.2.4
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\richa\\AppData\\Local\\Temp\\pip-uninstall-q3kanpbe\\pip.exe'
# Consider using the `--user` option or check the permissions.
# Collecting spacy
#   Downloading spacy-3.3.0-cp39-cp39-win_amd64.whl (11.6 MB)
#      ---------------------------------------- 11.6/11.6 MB 5.7 MB/s eta 0:00:00
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.3-cp39-cp39-win_amd64.whl (448 kB)
#      -------------------------------------- 448.4/448.4 kB 5.6 MB/s eta 0:00:00
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.2-py3-none-any.whl (7.2 kB)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\richa\anaconda3\lib\site-packages (from spacy) (1.20.3)
# Collecting thinc<8.1.0,>=8.0.14
#   Downloading thinc-8.0.17-cp39-cp39-win_amd64.whl (1.0 MB)
#      ---------------------------------------- 1.0/1.0 MB 6.6 MB/s eta 0:00:00
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.6-cp39-cp39-win_amd64.whl (36 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.6-cp39-cp39-win_amd64.whl (112 kB)
#      -------------------------------------- 112.4/112.4 kB 3.3 MB/s eta 0:00:00
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.7-py3-none-any.whl (17 kB)
# Requirement already satisfied: setuptools in c:\users\richa\anaconda3\lib\site-packages (from spacy) (62.3.2)
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4
#   Downloading pydantic-1.8.2-cp39-cp39-win_amd64.whl (1.9 MB)
#      ---------------------------------------- 1.9/1.9 MB 6.2 MB/s eta 0:00:00
# Collecting blis<0.8.0,>=0.4.0
#   Downloading blis-0.7.7-cp39-cp39-win_amd64.whl (6.6 MB)
#      ---------------------------------------- 6.6/6.6 MB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\richa\anaconda3\lib\site-packages (from spacy) (4.62.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\richa\anaconda3\lib\site-packages (from spacy) (2.26.0)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      -------------------------------------- 181.6/181.6 kB 5.5 MB/s eta 0:00:00
# Collecting pathy>=0.3.5
#   Downloading pathy-0.6.1-py3-none-any.whl (42 kB)
#      ---------------------------------------- 42.8/42.8 kB 2.0 MB/s eta 0:00:00
# Collecting wasabi<1.1.0,>=0.9.1
#   Downloading wasabi-0.9.1-py3-none-any.whl (26 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.7-cp39-cp39-win_amd64.whl (18 kB)
# Requirement already satisfied: jinja2 in c:\users\richa\anaconda3\lib\site-packages (from spacy) (2.11.3)
# Collecting spacy-legacy<3.1.0,>=3.0.9
#   Downloading spacy_legacy-3.0.9-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\richa\anaconda3\lib\site-packages (from spacy) (21.0)
# Collecting typer<0.5.0,>=0.3.0
#   Downloading typer-0.4.1-py3-none-any.whl (27 kB)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\richa\anaconda3\lib\site-packages (from packaging>=20.0->spacy) (3.0.4)
# Collecting smart-open<6.0.0,>=5.0.0
#   Downloading smart_open-5.2.1-py3-none-any.whl (58 kB)
#      ---------------------------------------- 58.6/58.6 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\richa\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy) (3.10.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\richa\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.5.18.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\richa\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\richa\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\richa\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.2)
# Requirement already satisfied: colorama in c:\users\richa\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\richa\anaconda3\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy) (8.0.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\richa\anaconda3\lib\site-packages (from jinja2->spacy) (1.1.1)
# Installing collected packages: wasabi, murmurhash, cymem, spacy-loggers, spacy-legacy, smart-open, pydantic, preshed, langcodes, catalogue, blis, typer, srsly, thinc, pathy, spacy
# Successfully installed blis-0.7.7 catalogue-2.0.7 cymem-2.0.6 langcodes-3.3.0 murmurhash-1.0.7 pathy-0.6.1 preshed-3.0.6 pydantic-1.8.2 smart-open-5.2.1 spacy-3.3.0 spacy-legacy-3.0.9 spacy-loggers-1.0.2 srsly-2.4.3 thinc-8.0.17 typer-0.4.1 wasabi-0.9.1
# Collecting en-core-web-sm==3.3.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.3.0/en_core_web_sm-3.3.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 12.8/12.8 MB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.4.0,>=3.3.0.dev0 in c:\users\richa\anaconda3\lib\site-packages (from en-core-web-sm==3.3.0) (3.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\richa\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (4.62.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\richa\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (21.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\richa\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.7.7)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\richa\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.3.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\richa\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.0.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\richa\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.0.7)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\richa\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.8.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in c:\users\richa\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.0.9)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\richa\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.26.0)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\richa\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.20.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\richa\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.0.6)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\richa\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.4.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\richa\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.9.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\richa\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.4.3)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\richa\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.6.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\richa\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.0.7)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in c:\users\richa\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (8.0.17)
# Requirement already satisfied: jinja2 in c:\users\richa\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.11.3)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\richa\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.0.2)
# Requirement already satisfied: setuptools in c:\users\richa\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (62.3.2)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\richa\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\richa\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\richa\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.10.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\richa\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2022.5.18.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\richa\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\richa\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\richa\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.26.7)
# Requirement already satisfied: colorama in c:\users\richa\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.4.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\richa\anaconda3\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (8.0.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\richa\anaconda3\lib\site-packages (from jinja2->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.1.1)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.3.0
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Import library.
import spacy

# Load the English resource.
nlp = spacy.load('en_core_web_sm')

# Return the text snippet and its corresponding entity label in a list.
def generate_named_entities(comment):
    return [(ent.text.strip(), ent.label_) for ent in nlp(comment).ents]

# %%
survey['named_entities'] = survey['COMMENTS'].apply(generate_named_entities)

survey.head()
# Out:
#    index          X          Y  OBJECTID  \
# 0      0 -77.020315  38.892890         1
# 1      1 -77.020877  38.893046         2
# 2      2 -77.024643  38.918125         3
# 3      3 -77.003515  38.896124         4
# 4      4 -77.017562  38.883266         5
#
#                                  GLOBALID REQUESTID    USERTYPE  \
# 0  {7AA2347A-C035-4D5A-9196-07C309B4C7BF}         1  Pedestrian
# 1  {1AFF4069-5D94-49A1-9D1F-0A089D414F5F}         2  Pedestrian
# 2  {908CCF07-A389-40EE-B5D2-7ADAF90404D1}         3  Pedestrian
# 3  {12E7A594-76F9-41CE-91AC-9B6B8E08EC5C}         4  Pedestrian
# 4  {0AED48A8-A4DD-44E9-8C4A-D45E14E7462D}         5       Biker
#
#                 REQUESTTYPE             REQUESTDATE      STATUS  STREETSEGID  \
# 0    Blocking the crosswalk  2015/06/29 19:56:00+00  Unassigned      10022.0
# 1       Other Driving Issue  2015/06/29 19:57:36+00  Unassigned      10022.0
# 2  Not enough time to cross  2015/06/29 20:14:32+00  Unassigned      10396.0
# 3         Stop sign running  2015/06/29 20:15:02+00  Unassigned       4381.0
# 4          Cyclist behavior  2015/06/29 20:15:05+00  Unassigned       5344.0
#
#                                             COMMENTS  \
# 0  cars for valet at the capital grille constantl...
# 1                                illegal uturns here
# 2  there is no walk sign on this intersection so ...
# 3  constant issue mpd never enforces despite repe...
# 4             some cyclists often run this red light
#
#                                               tokens  polarity  subjectivity  \
# 0  [cars, for, valet, at, the, capital, grille, c...  0.000000      0.333333
# 1                            [illegal, uturns, here] -0.500000      0.500000
# 2  [there, is, no, walk, sign, on, this, intersec...  0.233333      0.500000
# 3  [constant, issue, mpd, never, enforces, despit...  0.000000      0.333333
# 4     [some, cyclists, often, run, this, red, light]  0.200000      0.350000
#
#      named_entities
# 0                []
# 1                []
# 2  [(vermont, GPE)]
# 3                []
# 4                []

# %% [markdown]
# ## Visualise named entities

# %%
# Import library.
from spacy import displacy

# Iterate through a selection of comments.
for i in range(750, 1750):
    # Check whether the corresponding comment has a named entity.
    if survey['named_entities'][i]:
        # Highlight the entity in the comment.
        displacy.render(nlp(survey['COMMENTS'][i]), style = 'ent', jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">temporary crossing signal across
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4th st
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  nw on north side of massachussetts ave during construction is set incorrectly so it only allows crossing when mass ave has green signal but not when h st does even though it is safe for pedestrians then</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">outbound drivers from montana onto ny ave outbound usually block the box mostly during
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pm rush hours
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     unnecessarily long red light very little
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  pedestrian traffic tofrom
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     howard
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and tofrom mcmillan</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">construction workers and school parking often block this crosswalk and right turn lane onto
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mount olivet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  rd ne from
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     9th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  st ne</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">motorists exiting logan circle south to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     13th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  street often run the red light at o st at very high speed i nearly get hit a few times each month</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">i occasionally see motorists driving the wrong way down m
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     st at night
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  between
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     connecticut
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     17th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  st</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">the pedestrian island was removed
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and this intersection is now unbelievably dangerous for pedestrians</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">cars turning left from m to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     21st
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  fail to stop for pedestrians no clearly marked left turn lane just a very wide single lane means cars in parallel to one another often both try the left turn at the same time</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">lights on both sides of the intersection make it impossible to cross pennsylvania on
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  cycle</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">the walk sign is not long enough to cross before drivers get the green arrow to turn right from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     massachusetts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  onto
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     9th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  street</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">northbound motorists on
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     vermont
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  turning right on o usually cut the corner over the bike lane very dangerous could benefit from flexposts being installed at the turn to protect cyclists</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">motorists harass and honk
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5sec
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sustained at cyclists regularly on this block even when there is a red light ahead police enforcement is needed to protect cyclists</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">drivers will often cut from traveling ne on
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     new york
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  ave to traveling e on l street at high rates of speed without yielding to pedestrians crossing
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  street along
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     new york
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">the walk sign crossing
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  street from l street should be automatic pedestrians should not need to press the button there is also a long wait to cross  can pedestrians cross
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  at l when the light is green for ny ave traffic too</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">there should be a crosswalk here as many people cross and there is poor visibility due to parked cars sometimes walking down l to cross at
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  is not an option for pedestrian safety reasons construction rowdy behavior at park on corner</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">its very difficult for a cyclists to comfortably cross this intersection either to turn left from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     florida
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  onto
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     connecticut
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  or to continue straight on
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     florida
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  the right turn slip lane for cars is a big part of it</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">cars turning left onto
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     17th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  from new hampshire consistently do not see pedestrians crossing
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     17th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  this needs a left arrow to avoid the possibility of a car hitting a ped  just like at
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     16th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     u
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and nh</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">the northfacing street light on the sw corner of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  and e is out due to construction on that lot this means you have to see the light on the southeast corner to know what the signal is this confuses vehicles that either stop or go randomly</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">needs striped crosswalk and signage for uncontrolled intersection at
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     16th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     swann
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">no bike lane or dedicated sidewalks for cyclists on
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nebraska
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">when will ddot finally install the planned bike lanes on woodley it has been
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3 years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">please extend the cycle track all the way to hains point the stretch of road on
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     15th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  from where the track ends to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     maine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is frightening on the bike during rush hour which is why you see so many cyclists on the sidewalk even though it is forbidden</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">cars routinely block the pedestrian crossing and park in front of the curb where pedestrians enter the crossing cars also use the pedestrian crossing path to perform uturns on to westbound
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     maine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  ave needs much clearer lines and signage</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">i cross this street
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     every morning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  and often drivers heading north on
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  do not stop at the stop sign thanks for the effort</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">drivers on
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     piney
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  branch frequently run the light drivers on butternut frequently make turns without looking for pedestrians i think this intersection needs a red light camera</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">the traffic light does not change for cyclists  i have waited
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than 5 minutes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  at this intersection a couple of times
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     early morning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  before
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     7am
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  and i cannot spot any sensors while lights in other intersections do change</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">in all the intersections in this area drivers run red lights frequently as a matter of fact all over
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dc
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  drivers seem to think that a yellow light means accelerate they end up running red lights or blocking streets as a consequence</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">cyclists constantly use the sidewalk up and down
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     14th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  instead of the bike lanes</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">there is a tree just outside of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1909
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  constitution ave ne between the sidewalk and road that is
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     45
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  dead a large branch fell off and is now in the road the rest of the tree appears to be likely to fall down soon</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  jaywalking issues
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  ingleside employees jaywalk from e4 buses across military 2 wilson and deal students transferring from e4 buses to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     m4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  buses jaywalk across
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     30th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  place</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">people routinely park along the sidewalk bulb out making it difficult for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  lanes of traffic to pass ive even seen someone get sideswiped here
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  time because they were parked poorly</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">the crosswalk on the west side of this intersection has
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     only ten seconds
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  to cross a relatively wide stretch of c street this is a fraction of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the 20 seconds
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  available to pedestrians on the east side of the intersection</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">while there are crosswalks there are no stop signs this is confusing to pedestrians and drivers alike as they subconsciously assume that e street traffic will stop at
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     23rd
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  place</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">entrance to alley and all of the wylie
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     st alley streets
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  are crumbling pot holes continue to show up and city and work vehicles are main contributors to this you cannot drive or walk safely due to the condition of the streets they must be repaired</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">streets on wylie st east of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     13th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  street  are in really bad shape i tripped and fell and there is gravel everywhere</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">cars on
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  st nw are usually backed up and will run the light to cross ny ave nw when crossing
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  st as a pedestrian cars trying to make a left turn from ny ave nw have difficulty spotting pedestrians who are crossing
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">the redlight at windom and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     conn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  heading northbound on
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     conn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is hard to see causing drivers to run the redlight</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">pedestrian signal timers are routinely hit by trucks turning from ny ave nw onto 1st st nw timers have always been hit and turned askew therefore not visible to pedestrians submitted multiple
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     311
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  tickets they get fixed and routinely hit again</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">too long of a wait for pedestrians to cross ny ave also very dangerous with cars running red lights to avoid waiting longer to get onto
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     395
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">drivers frequently speed when approaching right turn onto
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     franklin st
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  ne often not seeing pedestrians til
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last minute
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  due to a big tree blinding the pedestrian crossing and speeding</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">should be a fourway stop difficult sight lights for drivers on legation attempting to cross
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     31st
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  street there have been multiple accidents in the past</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pedestrian signal installed upside
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  down</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">motorists exiting office building make illegal left turn up oneway street to use the buildings back alley as a shortcut to northbound
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3rd
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  street se the maneuver cuts off pedestrians and a bike lane and potentially southbound motorists</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">confusing intersection because westbound
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     florida
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  light stays green
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     15 seconds
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  longer than eastbound
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     florida
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  light pedestrians see
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  red light and start to cross not clear how it helps traffic flow to have mismatched signal timing</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">very difficult to cross irving walking west on
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     michigan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  because bushes block the view of westbound
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     michigan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  vehicles</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">guard railing around metro chiller plant behind woodson row
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     19161922 12th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  street nw restricts access to alley making it nearly impossible to enter alley from northern entrance guard railing needs to be shiftedshortened on northern end</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">on ramps onto and off
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     295
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  from penn ave all directions there is no stopping for pedestrians cyclist crossing sousa bridge ddot could start by restriping crosswalks then some enforcement by mpd</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">alabama ave se at all marked intersections
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     between 30th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  st and branch ave cars do not stop for pedestrians need flashing lights and enforcement</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">many drivers run the red light in the slip lane from k street to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     connecticut
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  northbound by treating it like a right on red this is a very unsafe situation given all of the pedestrians coming from the farragut metro exit at this corner</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">cars rushing to make the green light at
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     11th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  frequently fail to yield to pedestrians all of these crosswalks should be protected with stop signs several could also use revised parking for better sight lines</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">the turn signals from m
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     st onto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  st are in an unusual cycle and are hard to see by pedestrians pedestrians see the do no walk sign but see the light is red and attempt to cross not realizing the cars have a green turn arrow</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">some drivers treat 39th between
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     rodman
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     massachusetts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  as a speedway</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">motor vehicles fail to yield to pedestrians and use excessive speed as
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     potomac
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  avenue turns into oneway after
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     18th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  street signage on this portion of the intersection western crosswalk near e street are posted too high for motorists to notice</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">there needs to be a crosswalk here  there is a bus stop that lets off on the river park side but the closest crosswalks are at canal or
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  street a crosswalk is needed to allow people to get to the community center more easily</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">the sidewalk here is torn up from trees it is impossible to get by via wheelchair and very difficult to for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  pedestrians to pass abreast</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">with
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     virginia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  avenue closed here why not have the signals flashing yellow for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fourth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  street there areno turns so no need to stop northsouth traffic thanks</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">cars continuing on
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     u st east
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     florida
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  ave often do not stop at the red light continuing through when the very short 15
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     second
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  pedestrian light is on to cross u st</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">this section of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     rhode island
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  ave is riddled with potholes so cyclists are often forced to go into the middle lane of traffic which is extremely dangerous</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">street vendor often illegally parks in left turn lane during morning and
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     evening
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  rush hour periods  blocks both the turn lane and bottlenecks the bike lane</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">cars and trucks often turn right onto
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  street from the the middle lane not the righthand turn lane often cutting off cyclists and forcing them to either slam on the brakes or swerve onto the sidewalk to avoid hitting them</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">cars often drive way too fast down this section of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     new jersey
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  ave in both directions i witnessed a cyclist get hit by a car here after the car was speeding to go through a red light and the signal already turned green for traffic going east on q</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">peds crossing ct ave
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     18th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  st nw is a disaster drivers run the red lights and block the crosswalks forcing pedestrians into the traffic lanes there also simply isnt enough time on the crosswalk countdown to cross
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  lanes of traffic</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">why cant northbound traffic from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     maine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  onto
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     12th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ...
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     n  connecticut
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  especially in the morning ive never seen this enforced the street design seems to encourage this behavior</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">the light to cross independence and mass ave are very short given the high pedestrian and vehicle traffic southbound on
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     14th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">traffic coming from
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the east capitol
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  bridge continues to speed as it enters residential area</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">back in parking should be allowed on both sides of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     15th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  st given the width of the roadway there are increasingly scarce parking spots this could also increase safety as it would discourage passing on this section of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     15th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">westbound driver blast through here after they reach the section with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  lanes</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">drivers are reckless and aggressive at this intersection when going onto constitution or continuing on
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     north carolina
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  given the proximity to maury this is a safety issue</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">cars turning left sb onto
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  st from wb mass ave fail to yield to peds in crosswalk in their rush to avoid oncoming traffic cars make unsafe judgments and disregard peds in crosswalk</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">drivers blast down
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     rhode island
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  ave</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">in an area already difficult to have
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  cars pass cars are often double parked here
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     during school hours
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">the right turn from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     massachusetts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  onto north capitol has unsafe pedestriancar interactions every light cycle there needs to be a red arrow for right turners its dangerous</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">drivers turning from ne on
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     columbia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to east on euclid frequently make this turn very aggressively and narrowly miss pedestrians this turn should be banned</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">drivers go very fast down
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nebraska
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">the lights here are timed entirely way too long for pedestrians trying to cross
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     11th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LANGUAGE</span>
# </mark>
#  street minute long waits just invite jaywalking</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">there is no do not enter signs posted at this intersection like there are at the corner of fern and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  cars traveling eastbound on geranium often turn right to travel southbound on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  street which is
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  way northbound</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     thomas circle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is inefficient for pedestrians then they jaywalk and are at risk from cars that are going too fast retime the signals and add speed bumps for the cars</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">sidewalk is closed across the street from giant going south on
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3rd
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  street just blocked off</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">cars coming from
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     14th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  into
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     thomas circle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  are often going too fast</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">e
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     capitol bike lane
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  ends abruptly could it be connected to the penn ave bike lane</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">cars coming south on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     17th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  go extremely fast</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">this intersection is confusing for both pedestrians and drivers cars making righthand turns onto
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     23rd
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     virginia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  go barreling through the crosswalk across 23rd at f street pedestrians crossing
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     23rd
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  are at significant risk</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">southbound buses on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     23rd
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  often cannot make lefthand turns onto f street and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     virginia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  avenue until their signal has turned red this is quite hazardous for pedestrians using crosswalks across f and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     virginia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  recommend a lefthand dedicated signal</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">crossing here during
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the evening rush hour
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  is very dangerous cars which have doubleland righthand turn often fail to yield to pedestrians</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">the sidewalk on the western side of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     7th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  street is very uneven and dangerous for both wheelchairs and strollers but also small children who might trip and fall on their way to school</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">no sidewalks on this and other close blocks of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     blair
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  rd mean that pedestrians walk in the road there is a charter school nearby and students are also walking in the street on their way to and from the metro</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">serious speeding up and down
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     17th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  street</div></span>

# %% [markdown]
# ## Generate a document-term matrix

# %%
# [1] Import the necessary classes.
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize import RegexpTokenizer

# [2] Use a tokenizer object to remove unwanted elements.
token = RegexpTokenizer(r'[a-zA-Z0-9]+')

# [3] Create a CountVectorizer object to process the comments.
cv = CountVectorizer(lowercase = True, stop_words = 'english',
                     ngram_range = (1, 1), tokenizer = token.tokenize)

# [4] Apply the transformation to the comment data.
cvs = cv.fit_transform(survey['COMMENTS'])

# %%
# Create a DataFrame.
dt = pd.DataFrame(cvs.todense()).iloc[:15]  

# Name the columns.
dt.columns = cv.get_feature_names()

# Transpose columns and headings.
document_term_matrix = dt.T

# Update the column names.
document_term_matrix.columns = ['Doc ' + str(i) for i in range(1, 16)]

# Get the totals.
document_term_matrix['total_count'] = document_term_matrix.sum(axis = 1)

# Identify the top 10 words 
document_term_matrix = document_term_matrix.sort_values(by = 'total_count', 
                                                        ascending = False)[:10] 

# Display the results.
print(document_term_matrix.drop(columns = ['total_count']).head(10))
# Out:
#            Doc 1  Doc 2  Doc 3  Doc 4  Doc 5  Doc 6  Doc 7  Doc 8  Doc 9  \
# red            0      0      0      0      1      0      0      0      1
# bike           0      0      0      0      0      0      1      1      0
# traffic        0      0      0      0      0      0      0      0      1
# st             0      0      0      0      0      0      1      0      1
# block          1      0      0      0      0      0      1      0      0
# crosswalk      1      0      0      0      0      0      0      0      1
# right          0      0      0      0      0      0      0      0      0
# signal         0      0      0      0      0      0      0      0      2
# light          0      0      1      0      1      0      0      0      0
# turn           0      0      1      0      0      0      0      0      0
#
#            Doc 10  Doc 11  Doc 12  Doc 13  Doc 14  Doc 15
# red             1       1       1       0       0       0
# bike            1       0       0       0       1       1
# traffic         1       1       0       0       1       0
# st              1       0       0       0       1       0
# block           0       1       0       0       0       1
# crosswalk       0       1       0       1       0       0
# right           1       1       0       0       1       0
# signal          0       0       0       0       1       0
# light           0       0       1       0       0       0
# turn            1       0       0       0       1       0

# %%
# Create visualisation.
document_term_matrix['total_count'].plot.barh(figsize = (12, 9), fontsize = 16,
                                             colormap = 'plasma')
# Out:
# <AxesSubplot:>
